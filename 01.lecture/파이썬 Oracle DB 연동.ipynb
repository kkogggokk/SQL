# %% [markdown]
# # cx_Oracle 모듈
# - 파이썬에서 오라클 DBMS와 연동는 다양한 함수를 제공하는 모듈
# - Python DB API 2.0 표준을 따른다.
#
# ## 참고
# - [cx_Oracle 모듈 홈페이지](https://oracle.github.io/python-cx_Oracle/)
# - [Python DB API](https://docs.python.org/ko/3/library/sqlite3.html)

# %% [markdown]
# ## cx_Oracle 모듈 설치
# - [설치 튜토리얼](https://cx-oracle.readthedocs.io/en/latest/user_guide/installation.html)
# - 패키지 설치
# ```
# conda install cx_oracle
# pip install cx_Oracle --upgrade
# ```

# %% [markdown]
# ## 코딩 절차
# 1. cx_Oracle 모듈 import

# %% [markdown]
# 2. cx_Oracle모듈의 connect() 함수를 이용해 디비연결 (방법3가지)
#     - 2.1
#     - 2.2
#     - 2.3

# %% [markdown]
# 3. Connection 객체의 cursor() 메소드를 이용해 Cursor객체 조회.
#     - Cursor객체: sql문을 전송하고 select결과 조회 기능을 제공하는 객체

# %% [markdown]
# 4. Cursor 의 execute() 메소드를 이용해 SQL문 전송

# %% [markdown]
# 5. SELECT 의 경우 결과 조회.
#     - 조회결과 한행씩 반환받아 사용
#     - 조회결과 한번에 반환받아 사용

# %% [markdown]
# 6. INSERT/DELETE/UPDATE의 경우  SQL 문 실행 후 Connection의 commit() 메소드를 이용해 Transaction 처리

# %% [markdown]
# 7. Cursor, Connection 연결 닫기

# %% [markdown]
# ### DB 연결
# - connect() 함수를 이용하며 연결 후 Connection 객체를 받는다.
# - 연결시 필요한 값
#     - **host**
#     - **port번호**
#     - **SID(DB이름)**
#     - **user name**
#     - **password**
#
# ### Connection 주요 메소드
# - commit(): 커밋
# - rollback(): 롤백
# - close(): 연결 닫기

# %%
# !pip install cx_Oracle
# Out:
# Requirement already satisfied: cx_Oracle in c:\users\playdata\anaconda3\lib\site-packages (8.1.0)

# %%
# connect()함수를 이용해서 연결시도 -> 연결 성공 시 Connection 객체를 반환 
# Connection 객체 : 연결정보를 가지고 있는 객체. 
import cx_Oracle 

username = 'c##scott_join'
password = 'tiger'
url = 'localhost:1521/XE' # 형식 : host:post/sid 

conn = cx_Oracle.connect(username, password, url) # 연결시도 -> 성공하면 connection 반환 
print(type(conn)) # 연결 성공하면 <class 'cx_Oracle.Connection'> 반환 
conn.close() # 접속해제
# Out:
# <class 'cx_Oracle.Connection'>

# %%
# username / pwd@url 형태 
conn2 = cx_Oracle.connect("c##scott_join/tiger@localhost:1521/XE")
print(type(conn2)) # <class 'cx_Oracle.Connection'>
conn2.close()
# Out:
# <class 'cx_Oracle.Connection'>

# %% [markdown]
# #### DSN (Data Source Name) 을 이용한 연결
# - DSN: DBMS를 연결하기 위한 정보를 모아 놓은 것. (서로 다른 DBMS의 연결정보를 통일하기 위해서 방식)
# - makedsn(host, port번호, SID) 함수 이용해 생성한다.

# %%
username = 'c##scott_join'
password = 'tiger'
host = 'localhost'
port = 1521
sid = 'XE'
dsn = cx_Oracle.makedsn(host, port, sid)
# print(dsn)
conn3 = cx_Oracle.connect(username, password, dsn)
print(conn3) # <cx_Oracle.Connection to c##scott_join@(DESCRIPTION=(ADDRESS=(PROTOCOL=TCP)(HOST=localhost)(PORT=1521))(CONNECT_DATA=(SID=XE)))>
conn3.close()
# Out:
# <cx_Oracle.Connection to c##scott_join@(DESCRIPTION=(ADDRESS=(PROTOCOL=TCP)(HOST=localhost)(PORT=1521))(CONNECT_DATA=(SID=XE)))>

# %%
# 연결하면 끊어줘야 한다. 이를 자동으로 하기 위해서 with절을 사용해서 편하게 구현 : with block
with cx_Oracle.connect(username, password, dsn) as conn4 : 
# db관련 작업코드 
    pass

# %% [markdown]
# ## Cursor 객체 (커서 - 데이터의 현재위치)
# - SQL문을 전송하고 select결과를 조회하는 메소드들을 제공한다.
# - Connection객체의 cursor() 메소드로 받아온다.

# %% [markdown]
# ### Cursor의 주요 메소드
# #### SQL 실행 메소드
# - execute(sql) : 하나의 sql 문 실행.
# - executemany(sql): insert, update, delete 배치 처리
#     - insert, update, delete는 다 처리후 conn.commit()으로 커밋 처리해야한다.

# %% [markdown]
# #### select 결과 조회 메소드
# - execute()로 실행한 SQL이 select인 경우 다음 메소드로 조회한다.
# - fetchall()  : 조회된 모든 행을 한번에 가져올 때 사용한다. 결과를 tuple들을 묶은 리스트로 반환
# - fetchone()  : 호출시 마다 한행씩 반환한다. PK로 조회한 경우 많이 사용한다.
# - fetchmany(n): n행만큼 조회한다. n기본값-100. 특정개수반큼 반복문을 이용해 가져올때 사용.

# %%
import cx_Oracle 
from pprint import pprint # 자료구조를 보기 좋게 출력해주는 print함수 

# SQL문은 문자열로 작성. 
# 대소문자 구분안한다. 단, SQL의 키워드(SELECT, FROM, WHERE 등)은 보통 대문자로 , 컬럼명/테이블명은 소문자로 작성하는 것이 관례 
#  세미콜로(;)은 붙이지 않는다. 
# 주의 : 넣는 값 싱따옴표 구분해줘야함.why? 문자열이기 때문에  
select_sql = "SELECT emp_id, emp_name, job_id FROM emp"
insert_sql = "INSERT INTO emp VALUES (1500, '홍길동', 'FI_ACCOUNT', 101, to_date('2021/02/15','yyyy/mm/dd'), 30000, 0.23, 100)"  # 날짜형태 입력 시 to_date로 변환해서 
conn = None # Connection을 대입할 변수 
cursor = None

#INSERT 후에 SELECT 실행하기 -> commit 해줘야 db에 적용된다. 
try : 
    # 1. 연결 
    conn = cx_Oracle.connect('c##scott_join/tiger@localhost:1521/xe')
    print(conn," : 연결완료")
    
    # 2. cursor생성 
    cursor = conn.cursor()
    
    # 3. sql실행 
    cursor.execute(insert_sql)
    cursor.execute(select_sql)
    
    # 4. select 결과 조회
    result = cursor.fetchall() # 조회결과를 한번에 반환, 한행 - Tuple, 리스트로 튜플들을 묶어서 반환
    
    print(type(result), type(result[0])) # <class 'list'> <class 'tuple'>
    print(len(result))
    pprint(result)
    
    # 5. insert / update / delete 를 실행한 경우 commit 처리 **중요! 
    conn.commit()
    
except Exceptions as e : # 예외처리 
    print(e)
    
finally : 
    # 6. 연결 닫기 - connection, cursor 
    if cursor != None : 
        cursor.close()
    if conn != None :
        conn.close()
# Out:
# <cx_Oracle.Connection to c##scott_join@localhost:1521/xe>  : 연결완료
# <class 'list'> <class 'tuple'>
# 108
# [(100, 'Steven', 'AD_PRES'),
#  (101, 'Neena', 'AD_VP'),
#  (102, 'Lex', 'AD_VP'),
#  (103, 'Alexander', 'IT_PROG'),
#  (104, 'Bruce', 'IT_PROG'),
#  (105, 'David', 'IT_PROG'),
#  (106, 'Valli', 'IT_PROG'),
#  (107, 'Diana', 'IT_PROG'),
#  (108, 'Nancy', 'FI_MGR'),
#  (109, 'Daniel', 'FI_ACCOUNT'),
#  (110, 'John', 'FI_ACCOUNT'),
#  (111, 'Ismael', 'FI_ACCOUNT'),
#  (112, 'Jose Manuel', 'FI_ACCOUNT'),
#  (113, 'Luis', 'FI_ACCOUNT'),
#  (114, 'Den', 'PU_MAN'),
#  (115, 'Alexander', 'PU_MAN'),
#  (116, 'Shelli', 'PU_CLERK'),
#  (117, 'Sigal', 'PU_CLERK'),
#  (118, 'Guy', 'PU_CLERK'),
#  (119, 'Karen', 'PU_CLERK'),
#  (120, 'Matthew', 'ST_MAN'),
#  (121, 'Adam', 'ST_MAN'),
#  (122, 'Payam', 'ST_MAN'),
#  (123, 'Shanta', 'ST_MAN'),
#  (124, 'Kevin', 'ST_MAN'),
#  (125, 'Julia', 'ST_CLERK'),
#  (126, 'Irene', 'ST_CLERK'),
#  (127, 'James', 'ST_CLERK'),
#  (128, 'Steven', 'ST_CLERK'),
#  (129, 'Laura', 'ST_CLERK'),
#  (130, 'Mozhe', None),
#  (131, 'James', None),
#  (132, 'TJ', 'ST_CLERK'),
#  (133, 'Jason', 'ST_CLERK'),
#  (134, 'Michael', 'ST_CLERK'),
#  (135, 'Ki', 'ST_CLERK'),
#  (136, 'Hazel', 'ST_CLERK'),
#  (137, 'Renske', 'ST_CLERK'),
#  (138, 'Stephen', 'ST_CLERK'),
#  (139, 'John', 'ST_CLERK'),
#  (140, 'Joshua', None),
#  (141, 'Trenna', 'ST_CLERK'),
#  (142, 'Curtis', 'ST_CLERK'),
#  (143, 'Randall', 'ST_CLERK'),
#  (144, 'Peter', 'ST_CLERK'),
#  (145, 'John', 'SA_MAN'),
#  (146, 'Karen', 'SA_MAN'),
#  (147, 'Alberto', 'SA_MAN'),
#  (148, 'Gerald', 'SA_MAN'),
#  (149, 'Eleni', 'SA_MAN'),
#  (150, 'Peter', 'SA_REP'),
#  (151, 'David', 'SA_REP'),
#  (152, 'Peter', 'SA_REP'),
#  (153, 'Christopher', 'SA_REP'),
#  (154, 'Nanette', 'SA_REP'),
#  (155, 'Oliver', 'SA_REP'),
#  (156, 'Janette', 'SA_REP'),
#  (157, 'Patrick', 'SA_REP'),
#  (158, 'Allan', 'SA_REP'),
#  (159, 'Lindsey', 'SA_REP'),
#  (160, 'Louise', 'SA_REP'),
#  (161, 'Sarath', 'SA_REP'),
#  (162, 'Clara', 'SA_REP'),
#  (163, 'Danielle', 'SA_REP'),
#  (164, 'Mattea', 'SA_REP'),
#  (165, 'David', 'SA_REP'),
#  (166, 'Sundar', 'SA_REP'),
#  (167, 'Amit', 'SA_REP'),
#  (168, 'Lisa', 'SA_REP'),
#  (169, 'Harrison', 'SA_REP'),
#  (170, 'Tayler', 'SA_REP'),
#  (171, 'William', 'SA_REP'),
#  (172, 'Elizabeth', 'SA_REP'),
#  (173, 'Sundita', 'SA_REP'),
#  (174, 'Ellen', 'SA_REP'),
#  (175, 'Alyssa', 'SA_REP'),
#  (176, 'Jonathon', 'SA_REP'),
#  (177, 'Jack', 'SA_REP'),
#  (178, 'Kimberely', 'SA_REP'),
#  (179, 'Charles', 'SA_REP'),
#  (180, 'Winston', 'SH_CLERK'),
#  (181, 'Jean', 'SH_CLERK'),
#  (182, 'Martha', 'SH_CLERK'),
#  (183, 'Girard', 'SH_CLERK'),
#  (184, 'Nandita', 'SH_CLERK'),
#  (185, 'Alexis', 'SH_CLERK'),
#  (186, 'Julia', 'SH_CLERK'),
#  (187, 'Anthony', None),
#  (188, 'Kelly', 'SH_CLERK'),
#  (189, 'Jennifer', 'SH_CLERK'),
#  (190, 'Timothy', None),
#  (191, 'Randall', None),
#  (192, 'Sarah', 'SH_CLERK'),
#  (193, 'Britney', 'SH_CLERK'),
#  (194, 'Samuel', 'SH_CLERK'),
#  (195, 'Vance', 'SH_CLERK'),
#  (196, 'Alana', 'SH_CLERK'),
#  (197, 'Kevin', 'SH_CLERK'),
#  (198, 'Donald', 'SH_CLERK'),
#  (199, 'Douglas', 'SH_CLERK'),
#  (200, 'Jennifer', 'AD_ASST'),
#  (201, 'Michael', 'MK_MAN'),
#  (202, 'Pat', 'MK_REP'),
#  (203, 'Susan', 'HR_REP'),
#  (204, 'Hermann', 'PR_REP'),
#  (205, 'Shelley', 'AC_MGR'),
#  (206, 'William', 'AC_ACCOUNT'),
#  (1500, '홍길동', 'FI_ACCOUNT')]

# %% [markdown]
# ## placeholder(자리표시자)를 이용해 sql 실행
# - SQL에 값이 들어갈 자리에 값을 대신할 문자 **`:순번` 또는 `:이름`** 를 넣고 SQL 실행시 값을 전달
# > placehold 는 DBMS마다 다르다.
# - execute(SQL, placeholder에 들어갈 값)
#     - 딕셔너리: placeholder의 이름-값 형식
#     - 리스트나 튜플: placeholder 순서

# %%
import cx_Oracle
from pprint import pprint

# %%
select_sql = "SELECT * FROM emp WHERE salary BETWEEN :1 AND :2" # 값 변경할거니 자리 차리하고 있어라. placeholder 
insert_sql = "INSERT INTO emp VALUES (:id, :name, :job_id, :mgr_id, :to_date(:hire_date,'yyyymmdd'), :salary, :comm_pct, :dept_id)"

conn = None
cursor = None

try :
    conn = cx_Oracle.connect('c##scott_join/tiger@localhost:1521/xe')
    cursor = conn.cursor()
    
    # SQL문 실행 
    # varchar2 / char / nvarchar / nchar - str 
    # number (정수/실수) - int / double 
    # date - datetime 모듈 , 지금은 to_date로 문자열을 변환하는 형태로 
    # null - None 
    param_dict = {
        'id' : 2000,
        'name' : '이순신', 
        'job_id' : 'FI_ACCOUNT', 
        'mgr_id' : 101, 
        'hire_date' : '20210213', 
        'salary' : 19990,
        'comm_pct' : None, 
        'dept_id' : 110
    }
    cursor.execute(insert_sql, param_dict)
    result0 = cursor.fetchall()
    pprint(result0)
    
#     cursor.execute(select_sql, [10000, 20000]) # 리스트나 튜플로 값을 알려준다. 
#     result1 = cursor.fetchall()
#     print("10000 ~ 20000 사이 조회")
#     pprint(result1)
    
#     cursor.execute(select_sql, [20000, 30000]) # 리스트나 튜플로 값을 알려준다. 
#     print("20000 ~ 30000 사이 조회")
#     result2 = cursor.fetchall()
#     pprint(result2)
    
    conn.commit()
     
except Exception as e :
    print(e)
    
finally: 
    if cursor != None :
        cursor.close()
    if conn != None : 
        conn.close()
# Out:
# ORA-01008: 일부 변수가 바인드되지 않았습니다.

# %% [markdown]
# ## SELECT  결과 조회
#
# ### fetchone()
# - 조회결과 한행씩 반환한다.
# - PK로 조회시 사용한다.
# - 반환타입 : tuple

# %% [markdown]
# ### fetchall()
# - 조회한 전체 결과셋을 반환한다.
# - 한 row를 Tuple로 묶고 그 Tuple들을 List로 묶어서 반환한다.

# %% [markdown]
# ### fetchmany(n)
# - n 행씩 조회할 때 사용
# - n 기본값 100

# %%
# emp_id(PK)로 직원정보를 조회하는 함수 
def select_emp_by_id(emp_id) :
#     conn, cursor = None, None 
    sql = "SELECT * FROM emp WHERE emp_id = :1"
    with cx_Oracle.connect('c##scott_join/tiger@localhost:1521/XE') as conn : 
        with conn.cursor() as cursor : 
            # sql실행 
            cursor.execute(sql, [emp_id])
            result = cursor.fetchone() # 1행 조회(튜플로 반환). 조회결과가 없으면 None을 반환 
            return result 
        cursor.close()
    conn.close()

# %%
r = select_emp_by_id(100)
print(r)
print("id:",r[0], "이름:",r[1])
# Out:
# (100, 'Steven', 'AD_PRES', None, datetime.datetime(2003, 6, 17, 0, 0), 24000.0, None, 90)
# id: 100 이름: Steven

# %%
r = select_emp_by_id(3000)
print(r)
# Out:
# None

# %%
r = select_emp_by_id(100)
r = select_emp_by_id(3000)
if r != None :
    print(r)
else :
    print('조회결과가 없습니다.', r)
# Out:
# 조회결과가 없습니다. None

# %%
sql = 'SELECT * FROM emp order by emp_id'
with cx_Oracle.connect('c##scott/tiger@localhost:1521/XE') as conn : 
    with conn.cursor() as cursor : 
        cursor.execute(sql)
        result = cursor.fetchmany(10) # 10개만 조회
        print(len(result))
        print(result) # 100번 부터
        
        result = cursor.fetchmany(10)
        print(len(result))
        print(result) # 110번 부터 
        
        result = cursor.fetchmany(10)
        print(len(result))
        print(result) # 120번 부터
        
        result = cursor.fetchmany(10)
        print(len(result))
        print(result) # 130번 부터 
        
        # len(result)가 0이면 빠져나와라 형태로 반복문 돌리수 있음
# Out:
# 10
# [(100, 'Steven', 'AD_PRES', None, datetime.datetime(2003, 6, 17, 0, 0), 24000.0, None, 'Executive'), (101, 'Neena', 'AD_VP', 100, datetime.datetime(2005, 9, 21, 0, 0), 17000.0, None, 'Executive'), (102, 'Lex', 'AD_VP', 100, datetime.datetime(2001, 1, 13, 0, 0), 17000.0, None, 'Executive'), (103, 'Alexander', 'IT_PROG', 102, datetime.datetime(2006, 1, 3, 0, 0), 9000.0, None, 'IT'), (104, 'Bruce', 'IT_PROG', 103, datetime.datetime(2007, 5, 21, 0, 0), 6000.0, None, 'IT'), (105, 'David', 'IT_PROG', 103, datetime.datetime(2005, 6, 25, 0, 0), 4800.0, None, 'IT'), (106, 'Valli', 'IT_PROG', 103, datetime.datetime(2006, 2, 5, 0, 0), 4800.0, None, 'IT'), (107, 'Diana', 'IT_PROG', 103, datetime.datetime(2007, 2, 7, 0, 0), 4200.0, None, 'IT'), (108, 'Nancy', 'FI_MGR', 101, datetime.datetime(2002, 8, 17, 0, 0), 12008.0, None, 'Finance'), (109, 'Daniel', 'FI_ACCOUNT', 108, datetime.datetime(2002, 8, 16, 0, 0), 9000.0, None, 'Finance')]
# 10
# [(110, 'John', 'FI_ACCOUNT', 108, datetime.datetime(2005, 9, 28, 0, 0), 8200.0, None, 'Finance'), (111, 'Ismael', 'FI_ACCOUNT', 108, datetime.datetime(2005, 9, 30, 0, 0), 7700.0, None, 'Finance'), (112, 'Jose Manuel', 'FI_ACCOUNT', 108, datetime.datetime(2006, 3, 7, 0, 0), 7800.0, None, 'Finance'), (113, 'Luis', 'FI_ACCOUNT', 108, datetime.datetime(2007, 12, 7, 0, 0), 6900.0, None, 'Finance'), (114, 'Den', 'PU_MAN', 100, datetime.datetime(2002, 12, 7, 0, 0), 11000.0, None, 'Purchasing'), (115, 'Alexander', 'PU_MAN', 100, datetime.datetime(2003, 5, 18, 0, 0), 7100.0, None, 'Purchasing'), (116, 'Shelli', 'PU_CLERK', 114, datetime.datetime(2005, 12, 24, 0, 0), 2900.0, None, 'Purchasing'), (117, 'Sigal', 'PU_CLERK', 115, datetime.datetime(2005, 7, 24, 0, 0), 2800.0, None, 'Purchasing'), (118, 'Guy', 'PU_CLERK', 115, datetime.datetime(2006, 11, 15, 0, 0), 2600.0, None, 'Purchasing'), (119, 'Karen', 'PU_CLERK', 114, datetime.datetime(2007, 8, 10, 0, 0), 2500.0, None, 'Purchasing')]
# 10
# [(120, 'Matthew', 'ST_MAN', 100, datetime.datetime(2004, 7, 18, 0, 0), 8000.0, None, 'Shipping'), (121, 'Adam', 'ST_MAN', 100, datetime.datetime(2005, 4, 10, 0, 0), 8200.0, None, 'Shipping'), (122, 'Payam', 'ST_MAN', 100, datetime.datetime(2003, 5, 1, 0, 0), 7900.0, None, 'Shipping'), (123, 'Shanta', 'ST_MAN', 100, datetime.datetime(2005, 10, 10, 0, 0), 6500.0, None, 'Shipping'), (124, 'Kevin', 'ST_MAN', 100, datetime.datetime(2007, 11, 16, 0, 0), 5800.0, None, 'Shipping'), (125, 'Julia', 'ST_CLERK', 120, datetime.datetime(2005, 7, 16, 0, 0), 3200.0, None, 'Shipping'), (126, 'Irene', 'ST_CLERK', 120, datetime.datetime(2006, 9, 28, 0, 0), 2700.0, None, 'Shipping'), (127, 'James', 'ST_CLERK', 120, datetime.datetime(2007, 1, 14, 0, 0), 2400.0, None, 'Shipping'), (128, 'Steven', 'ST_CLERK', 120, datetime.datetime(2008, 3, 8, 0, 0), 2200.0, None, 'Shipping'), (129, 'Laura', 'ST_CLERK', 121, datetime.datetime(2005, 8, 20, 0, 0), 3300.0, None, 'Shipping')]
# 10
# [(130, 'Mozhe', 'ST_CLERK', 121, datetime.datetime(2005, 10, 30, 0, 0), 2800.0, None, 'Shipping'), (131, 'James', 'ST_CLERK', 121, datetime.datetime(2005, 2, 16, 0, 0), 2500.0, None, 'Shipping'), (132, 'TJ', 'ST_CLERK', 121, datetime.datetime(2007, 4, 10, 0, 0), 2100.0, None, 'Shipping'), (133, 'Jason', 'ST_CLERK', 122, datetime.datetime(2004, 6, 14, 0, 0), 3300.0, None, 'Shipping'), (134, 'Michael', 'ST_CLERK', 122, datetime.datetime(2006, 8, 26, 0, 0), 2900.0, None, 'Shipping'), (135, 'Ki', 'ST_CLERK', 122, datetime.datetime(2007, 12, 12, 0, 0), 2400.0, None, 'Shipping'), (136, 'Hazel', 'ST_CLERK', 122, datetime.datetime(2008, 2, 6, 0, 0), 2200.0, None, 'Shipping'), (137, 'Renske', 'ST_CLERK', 123, datetime.datetime(2003, 7, 14, 0, 0), 3600.0, None, 'Shipping'), (138, 'Stephen', 'ST_CLERK', 123, datetime.datetime(2005, 10, 26, 0, 0), 3200.0, None, 'Shipping'), (139, 'John', 'ST_CLERK', 123, datetime.datetime(2006, 2, 12, 0, 0), 2700.0, None, 'Shipping')]

# %% [markdown]
# ### cursor를 for in 문을 이용해 select결과 조회
# - select후 cursor는 Iterable 한 객체.
# - cursor는 반복시마다 조회한 한행을 반환.

# %%
sql = "SELECT * from emp WHERE comm_pct IS NOT NULL ORDER BY emp_id"
with cx_Oracle.connect('c##scott_join/tiger@localhost:1521/XE') as conn :
    with conn.cursor() as cursor :
        cursor.execute(sql)
        
        for idx, row in enumerate(cursor,start=1) : #한번 반복 할 때마다 cursor.fetchone()을 실행 
            print(f'{idx} :',row)
# Out:
# 1 : (145, 'John', 'SA_MAN', 100, datetime.datetime(2004, 10, 1, 0, 0), 14000.0, 0.4, 80)
# 2 : (146, 'Karen', 'SA_MAN', 100, datetime.datetime(2004, 10, 1, 0, 0), 13500.0, 0.3, 80)
# 3 : (147, 'Alberto', 'SA_MAN', 100, datetime.datetime(2005, 3, 10, 0, 0), 12000.0, 0.3, 80)
# 4 : (148, 'Gerald', 'SA_MAN', 100, datetime.datetime(2007, 10, 15, 0, 0), 11000.0, 0.3, 80)
# 5 : (149, 'Eleni', 'SA_MAN', 100, datetime.datetime(2007, 10, 15, 0, 0), 10500.0, 0.2, 80)
# 6 : (150, 'Peter', 'SA_REP', 145, datetime.datetime(2007, 10, 15, 0, 0), 10000.0, 0.3, 80)
# 7 : (151, 'David', 'SA_REP', 145, datetime.datetime(2005, 3, 24, 0, 0), 9500.0, 0.25, 80)
# 8 : (152, 'Peter', 'SA_REP', 145, datetime.datetime(2005, 8, 20, 0, 0), 9000.0, 0.25, 80)
# 9 : (153, 'Christopher', 'SA_REP', 145, datetime.datetime(2006, 3, 30, 0, 0), 8000.0, 0.2, 80)
# 10 : (154, 'Nanette', 'SA_REP', 145, datetime.datetime(2006, 12, 9, 0, 0), 7500.0, 0.2, 80)
# 11 : (155, 'Oliver', 'SA_REP', 145, datetime.datetime(2007, 11, 23, 0, 0), 7000.0, 0.15, 80)
# 12 : (156, 'Janette', 'SA_REP', 146, datetime.datetime(2004, 1, 30, 0, 0), 10000.0, 0.35, 80)
# 13 : (157, 'Patrick', 'SA_REP', 146, datetime.datetime(2004, 3, 4, 0, 0), 9500.0, 0.35, 80)
# 14 : (158, 'Allan', 'SA_REP', 146, datetime.datetime(2004, 8, 1, 0, 0), 9000.0, 0.35, 80)
# 15 : (159, 'Lindsey', 'SA_REP', 146, datetime.datetime(2005, 3, 10, 0, 0), 8000.0, 0.3, 80)
# 16 : (160, 'Louise', 'SA_REP', 146, datetime.datetime(2005, 12, 15, 0, 0), 7500.0, 0.3, 80)
# 17 : (161, 'Sarath', 'SA_REP', 146, datetime.datetime(2006, 11, 3, 0, 0), 7000.0, 0.25, 80)
# 18 : (162, 'Clara', 'SA_REP', 147, datetime.datetime(2005, 11, 11, 0, 0), 10500.0, 0.25, 80)
# 19 : (163, 'Danielle', 'SA_REP', 147, datetime.datetime(2007, 3, 19, 0, 0), 9500.0, 0.15, 80)
# 20 : (164, 'Mattea', 'SA_REP', 147, datetime.datetime(2008, 1, 24, 0, 0), 7200.0, 0.1, 80)
# 21 : (165, 'David', 'SA_REP', 147, datetime.datetime(2008, 2, 23, 0, 0), 6800.0, 0.1, 80)
# 22 : (166, 'Sundar', 'SA_REP', 147, datetime.datetime(2008, 3, 24, 0, 0), 6400.0, 0.1, 80)
# 23 : (167, 'Amit', 'SA_REP', 147, datetime.datetime(2008, 4, 21, 0, 0), 6200.0, 0.1, 80)
# 24 : (168, 'Lisa', 'SA_REP', 148, datetime.datetime(2005, 3, 11, 0, 0), 11500.0, 0.25, 80)
# 25 : (169, 'Harrison', 'SA_REP', 148, datetime.datetime(2006, 3, 23, 0, 0), 10000.0, 0.2, 80)
# 26 : (170, 'Tayler', 'SA_REP', 148, datetime.datetime(2006, 1, 24, 0, 0), 9600.0, 0.2, 80)
# 27 : (171, 'William', 'SA_REP', 148, datetime.datetime(2007, 2, 23, 0, 0), 7400.0, 0.15, 80)
# 28 : (172, 'Elizabeth', 'SA_REP', 148, datetime.datetime(2007, 3, 24, 0, 0), 7300.0, 0.15, 80)
# 29 : (173, 'Sundita', 'SA_REP', 148, datetime.datetime(2008, 4, 21, 0, 0), 6100.0, 0.1, 80)
# 30 : (174, 'Ellen', 'SA_REP', 149, datetime.datetime(2004, 5, 11, 0, 0), 11000.0, 0.3, 80)
# 31 : (175, 'Alyssa', 'SA_REP', 149, datetime.datetime(2005, 3, 19, 0, 0), 8800.0, 0.25, None)
# 32 : (176, 'Jonathon', 'SA_REP', 149, datetime.datetime(2006, 3, 24, 0, 0), 8600.0, 0.2, 80)
# 33 : (177, 'Jack', 'SA_REP', 149, datetime.datetime(2006, 4, 23, 0, 0), 8400.0, 0.2, 80)
# 34 : (178, 'Kimberely', 'SA_REP', 149, datetime.datetime(2007, 5, 24, 0, 0), 7000.0, 0.15, None)
# 35 : (179, 'Charles', 'SA_REP', 149, datetime.datetime(2008, 1, 4, 0, 0), 6200.0, 0.1, 80)
# 36 : (1500, '홍길동', 'FI_ACCOUNT', 101, datetime.datetime(2021, 2, 15, 0, 0), 30000.0, 0.23, 100)

# %%
sql = "SELECT job_id, sum(salary), round(avg(salary),2) FROM emp GROUP BY job_id"

with cx_Oracle.connect("c##scott_join/tiger@localhost:1521/XE") as conn :
    with conn.cursor() as cursor : 
        cursor.execute(sql) 
        result = cursor.fetchall()
        pprint(result)
# Out:
# [('AD_VP', 34000, 17000),
#  ('FI_ACCOUNT', 69600, 11600),
#  ('PU_CLERK', 10800, 2700),
#  ('SH_CLERK', 55900, 3288.24),
#  ('HR_REP', 6500, 6500),
#  ('PU_MAN', 20100, 10050),
#  ('AC_MGR', 12008, 12008),
#  ('ST_CLERK', 47900, 2817.65),
#  ('AD_ASST', 4400, 4400),
#  ('IT_PROG', 28800, 5760),
#  (None, 16200, 2700),
#  ('SA_MAN', 61000, 12200),
#  ('AC_ACCOUNT', 8300, 8300),
#  ('FI_MGR', 12008, 12008),
#  ('ST_MAN', 36400, 7280),
#  ('AD_PRES', 24000, 24000),
#  ('MK_MAN', 13000, 13000),
#  ('SA_REP', 250500, 8350),
#  ('MK_REP', 6000, 6000),
#  ('PR_REP', 10000, 10000)]

# %%
sql = "SELECT e.emp_name, d.dept_name FROM emp e left join dept d ON d.dept_id = d.dept_id"
with cx_Oracle.connect("c##scott_join/tiger@localhost:1521/XE") as conn :
    with conn.cursor() as cursor : 
        cursor.execute(sql) 
        result = cursor.fetchall()
        pprint(result)
# Out:
# [('Steven', '기획부'),
#  ('Steven', '구매부'),
#  ('Steven', 'Administration'),
#  ('Steven', 'Marketing'),
#  ('Steven', 'Purchasing'),
#  ('Steven', 'Human Resources'),
#  ('Steven', 'Shipping'),
#  ('Steven', 'IT'),
#  ('Steven', 'Public Relations'),
#  ('Steven', 'Sales'),
#  ('Steven', 'Executive'),
#  ('Steven', 'Finance'),
#  ('Steven', 'Accounting'),
#  ('Steven', 'Treasury'),
#  ('Steven', 'Corporate Tax'),
#  ('Steven', 'Control And Credit'),
#  ('Steven', 'Shareholder Services'),
#  ('Steven', 'Benefits'),
#  ('Steven', 'Manufacturing'),
#  ('Steven', 'Construction'),
#  ('Steven', 'Contracting'),
#  ('Steven', 'Operations'),
#  ('Steven', 'IT Support'),
#  ('Steven', 'NOC'),
#  ('Steven', 'IT Helpdesk'),
#  ('Steven', 'Government Sales'),
#  ('Steven', 'Retail Sales'),
#  ('Steven', 'Recruiting'),
#  ('Steven', 'Payroll'),
#  ('Neena', '기획부'),
#  ('Neena', '구매부'),
#  ('Neena', 'Administration'),
#  ('Neena', 'Marketing'),
#  ('Neena', 'Purchasing'),
#  ('Neena', 'Human Resources'),
#  ('Neena', 'Shipping'),
#  ('Neena', 'IT'),
#  ('Neena', 'Public Relations'),
#  ('Neena', 'Sales'),
#  ('Neena', 'Executive'),
#  ('Neena', 'Finance'),
#  ('Neena', 'Accounting'),
#  ('Neena', 'Treasury'),
#  ('Neena', 'Corporate Tax'),
#  ('Neena', 'Control And Credit'),
#  ('Neena', 'Shareholder Services'),
#  ('Neena', 'Benefits'),
#  ('Neena', 'Manufacturing'),
#  ('Neena', 'Construction'),
#  ('Neena', 'Contracting'),
#  ('Neena', 'Operations'),
#  ('Neena', 'IT Support'),
#  ('Neena', 'NOC'),
#  ('Neena', 'IT Helpdesk'),
#  ('Neena', 'Government Sales'),
#  ('Neena', 'Retail Sales'),
#  ('Neena', 'Recruiting'),
#  ('Neena', 'Payroll'),
#  ('Lex', '기획부'),
#  ('Lex', '구매부'),
#  ('Lex', 'Administration'),
#  ('Lex', 'Marketing'),
#  ('Lex', 'Purchasing'),
#  ('Lex', 'Human Resources'),
#  ('Lex', 'Shipping'),
#  ('Lex', 'IT'),
#  ('Lex', 'Public Relations'),
#  ('Lex', 'Sales'),
#  ('Lex', 'Executive'),
#  ('Lex', 'Finance'),
#  ('Lex', 'Accounting'),
#  ('Lex', 'Treasury'),
#  ('Lex', 'Corporate Tax'),
#  ('Lex', 'Control And Credit'),
#  ('Lex', 'Shareholder Services'),
#  ('Lex', 'Benefits'),
#  ('Lex', 'Manufacturing'),
#  ('Lex', 'Construction'),
#  ('Lex', 'Contracting'),
#  ('Lex', 'Operations'),
#  ('Lex', 'IT Support'),
#  ('Lex', 'NOC'),
#  ('Lex', 'IT Helpdesk'),
#  ('Lex', 'Government Sales'),
#  ('Lex', 'Retail Sales'),
#  ('Lex', 'Recruiting'),
#  ('Lex', 'Payroll'),
#  ('Alexander', '기획부'),
#  ('Alexander', '구매부'),
#  ('Alexander', 'Administration'),
#  ('Alexander', 'Marketing'),
#  ('Alexander', 'Purchasing'),
#  ('Alexander', 'Human Resources'),
#  ('Alexander', 'Shipping'),
#  ('Alexander', 'IT'),
#  ('Alexander', 'Public Relations'),
#  ('Alexander', 'Sales'),
#  ('Alexander', 'Executive'),
#  ('Alexander', 'Finance'),
#  ('Alexander', 'Accounting'),
#  ('Alexander', 'Treasury'),
#  ('Alexander', 'Corporate Tax'),
#  ('Alexander', 'Control And Credit'),
#  ('Alexander', 'Shareholder Services'),
#  ('Alexander', 'Benefits'),
#  ('Alexander', 'Manufacturing'),
#  ('Alexander', 'Construction'),
#  ('Alexander', 'Contracting'),
#  ('Alexander', 'Operations'),
#  ('Alexander', 'IT Support'),
#  ('Alexander', 'NOC'),
#  ('Alexander', 'IT Helpdesk'),
#  ('Alexander', 'Government Sales'),
#  ('Alexander', 'Retail Sales'),
#  ('Alexander', 'Recruiting'),
#  ('Alexander', 'Payroll'),
#  ('Bruce', '기획부'),
#  ('Bruce', '구매부'),
#  ('Bruce', 'Administration'),
#  ('Bruce', 'Marketing'),
#  ('Bruce', 'Purchasing'),
#  ('Bruce', 'Human Resources'),
#  ('Bruce', 'Shipping'),
#  ('Bruce', 'IT'),
#  ('Bruce', 'Public Relations'),
#  ('Bruce', 'Sales'),
#  ('Bruce', 'Executive'),
#  ('Bruce', 'Finance'),
#  ('Bruce', 'Accounting'),
#  ('Bruce', 'Treasury'),
#  ('Bruce', 'Corporate Tax'),
#  ('Bruce', 'Control And Credit'),
#  ('Bruce', 'Shareholder Services'),
#  ('Bruce', 'Benefits'),
#  ('Bruce', 'Manufacturing'),
#  ('Bruce', 'Construction'),
#  ('Bruce', 'Contracting'),
#  ('Bruce', 'Operations'),
#  ('Bruce', 'IT Support'),
#  ('Bruce', 'NOC'),
#  ('Bruce', 'IT Helpdesk'),
#  ('Bruce', 'Government Sales'),
#  ('Bruce', 'Retail Sales'),
#  ('Bruce', 'Recruiting'),
#  ('Bruce', 'Payroll'),
#  ('David', '기획부'),
#  ('David', '구매부'),
#  ('David', 'Administration'),
#  ('David', 'Marketing'),
#  ('David', 'Purchasing'),
#  ('David', 'Human Resources'),
#  ('David', 'Shipping'),
#  ('David', 'IT'),
#  ('David', 'Public Relations'),
#  ('David', 'Sales'),
#  ('David', 'Executive'),
#  ('David', 'Finance'),
#  ('David', 'Accounting'),
#  ('David', 'Treasury'),
#  ('David', 'Corporate Tax'),
#  ('David', 'Control And Credit'),
#  ('David', 'Shareholder Services'),
#  ('David', 'Benefits'),
#  ('David', 'Manufacturing'),
#  ('David', 'Construction'),
#  ('David', 'Contracting'),
#  ('David', 'Operations'),
#  ('David', 'IT Support'),
#  ('David', 'NOC'),
#  ('David', 'IT Helpdesk'),
#  ('David', 'Government Sales'),
#  ('David', 'Retail Sales'),
#  ('David', 'Recruiting'),
#  ('David', 'Payroll'),
#  ('Valli', '기획부'),
#  ('Valli', '구매부'),
#  ('Valli', 'Administration'),
#  ('Valli', 'Marketing'),
#  ('Valli', 'Purchasing'),
#  ('Valli', 'Human Resources'),
#  ('Valli', 'Shipping'),
#  ('Valli', 'IT'),
#  ('Valli', 'Public Relations'),
#  ('Valli', 'Sales'),
#  ('Valli', 'Executive'),
#  ('Valli', 'Finance'),
#  ('Valli', 'Accounting'),
#  ('Valli', 'Treasury'),
#  ('Valli', 'Corporate Tax'),
#  ('Valli', 'Control And Credit'),
#  ('Valli', 'Shareholder Services'),
#  ('Valli', 'Benefits'),
#  ('Valli', 'Manufacturing'),
#  ('Valli', 'Construction'),
#  ('Valli', 'Contracting'),
#  ('Valli', 'Operations'),
#  ('Valli', 'IT Support'),
#  ('Valli', 'NOC'),
#  ('Valli', 'IT Helpdesk'),
#  ('Valli', 'Government Sales'),
#  ('Valli', 'Retail Sales'),
#  ('Valli', 'Recruiting'),
#  ('Valli', 'Payroll'),
#  ('Diana', '기획부'),
#  ('Diana', '구매부'),
#  ('Diana', 'Administration'),
#  ('Diana', 'Marketing'),
#  ('Diana', 'Purchasing'),
#  ('Diana', 'Human Resources'),
#  ('Diana', 'Shipping'),
#  ('Diana', 'IT'),
#  ('Diana', 'Public Relations'),
#  ('Diana', 'Sales'),
#  ('Diana', 'Executive'),
#  ('Diana', 'Finance'),
#  ('Diana', 'Accounting'),
#  ('Diana', 'Treasury'),
#  ('Diana', 'Corporate Tax'),
#  ('Diana', 'Control And Credit'),
#  ('Diana', 'Shareholder Services'),
#  ('Diana', 'Benefits'),
#  ('Diana', 'Manufacturing'),
#  ('Diana', 'Construction'),
#  ('Diana', 'Contracting'),
#  ('Diana', 'Operations'),
#  ('Diana', 'IT Support'),
#  ('Diana', 'NOC'),
#  ('Diana', 'IT Helpdesk'),
#  ('Diana', 'Government Sales'),
#  ('Diana', 'Retail Sales'),
#  ('Diana', 'Recruiting'),
#  ('Diana', 'Payroll'),
#  ('Nancy', '기획부'),
#  ('Nancy', '구매부'),
#  ('Nancy', 'Administration'),
#  ('Nancy', 'Marketing'),
#  ('Nancy', 'Purchasing'),
#  ('Nancy', 'Human Resources'),
#  ('Nancy', 'Shipping'),
#  ('Nancy', 'IT'),
#  ('Nancy', 'Public Relations'),
#  ('Nancy', 'Sales'),
#  ('Nancy', 'Executive'),
#  ('Nancy', 'Finance'),
#  ('Nancy', 'Accounting'),
#  ('Nancy', 'Treasury'),
#  ('Nancy', 'Corporate Tax'),
#  ('Nancy', 'Control And Credit'),
#  ('Nancy', 'Shareholder Services'),
#  ('Nancy', 'Benefits'),
#  ('Nancy', 'Manufacturing'),
#  ('Nancy', 'Construction'),
#  ('Nancy', 'Contracting'),
#  ('Nancy', 'Operations'),
#  ('Nancy', 'IT Support'),
#  ('Nancy', 'NOC'),
#  ('Nancy', 'IT Helpdesk'),
#  ('Nancy', 'Government Sales'),
#  ('Nancy', 'Retail Sales'),
#  ('Nancy', 'Recruiting'),
#  ('Nancy', 'Payroll'),
#  ('Daniel', '기획부'),
#  ('Daniel', '구매부'),
#  ('Daniel', 'Administration'),
#  ('Daniel', 'Marketing'),
#  ('Daniel', 'Purchasing'),
#  ('Daniel', 'Human Resources'),
#  ('Daniel', 'Shipping'),
#  ('Daniel', 'IT'),
#  ('Daniel', 'Public Relations'),
#  ('Daniel', 'Sales'),
#  ('Daniel', 'Executive'),
#  ('Daniel', 'Finance'),
#  ('Daniel', 'Accounting'),
#  ('Daniel', 'Treasury'),
#  ('Daniel', 'Corporate Tax'),
#  ('Daniel', 'Control And Credit'),
#  ('Daniel', 'Shareholder Services'),
#  ('Daniel', 'Benefits'),
#  ('Daniel', 'Manufacturing'),
#  ('Daniel', 'Construction'),
#  ('Daniel', 'Contracting'),
#  ('Daniel', 'Operations'),
#  ('Daniel', 'IT Support'),
#  ('Daniel', 'NOC'),
#  ('Daniel', 'IT Helpdesk'),
#  ('Daniel', 'Government Sales'),
#  ('Daniel', 'Retail Sales'),
#  ('Daniel', 'Recruiting'),
#  ('Daniel', 'Payroll'),
#  ('John', '기획부'),
#  ('John', '구매부'),
#  ('John', 'Administration'),
#  ('John', 'Marketing'),
#  ('John', 'Purchasing'),
#  ('John', 'Human Resources'),
#  ('John', 'Shipping'),
#  ('John', 'IT'),
#  ('John', 'Public Relations'),
#  ('John', 'Sales'),
#  ('John', 'Executive'),
#  ('John', 'Finance'),
#  ('John', 'Accounting'),
#  ('John', 'Treasury'),
#  ('John', 'Corporate Tax'),
#  ('John', 'Control And Credit'),
#  ('John', 'Shareholder Services'),
#  ('John', 'Benefits'),
#  ('John', 'Manufacturing'),
#  ('John', 'Construction'),
#  ('John', 'Contracting'),
#  ('John', 'Operations'),
#  ('John', 'IT Support'),
#  ('John', 'NOC'),
#  ('John', 'IT Helpdesk'),
#  ('John', 'Government Sales'),
#  ('John', 'Retail Sales'),
#  ('John', 'Recruiting'),
#  ('John', 'Payroll'),
#  ('Ismael', '기획부'),
#  ('Ismael', '구매부'),
#  ('Ismael', 'Administration'),
#  ('Ismael', 'Marketing'),
#  ('Ismael', 'Purchasing'),
#  ('Ismael', 'Human Resources'),
#  ('Ismael', 'Shipping'),
#  ('Ismael', 'IT'),
#  ('Ismael', 'Public Relations'),
#  ('Ismael', 'Sales'),
#  ('Ismael', 'Executive'),
#  ('Ismael', 'Finance'),
#  ('Ismael', 'Accounting'),
#  ('Ismael', 'Treasury'),
#  ('Ismael', 'Corporate Tax'),
#  ('Ismael', 'Control And Credit'),
#  ('Ismael', 'Shareholder Services'),
#  ('Ismael', 'Benefits'),
#  ('Ismael', 'Manufacturing'),
#  ('Ismael', 'Construction'),
#  ('Ismael', 'Contracting'),
#  ('Ismael', 'Operations'),
#  ('Ismael', 'IT Support'),
#  ('Ismael', 'NOC'),
#  ('Ismael', 'IT Helpdesk'),
#  ('Ismael', 'Government Sales'),
#  ('Ismael', 'Retail Sales'),
#  ('Ismael', 'Recruiting'),
#  ('Ismael', 'Payroll'),
#  ('Jose Manuel', '기획부'),
#  ('Jose Manuel', '구매부'),
#  ('Jose Manuel', 'Administration'),
#  ('Jose Manuel', 'Marketing'),
#  ('Jose Manuel', 'Purchasing'),
#  ('Jose Manuel', 'Human Resources'),
#  ('Jose Manuel', 'Shipping'),
#  ('Jose Manuel', 'IT'),
#  ('Jose Manuel', 'Public Relations'),
#  ('Jose Manuel', 'Sales'),
#  ('Jose Manuel', 'Executive'),
#  ('Jose Manuel', 'Finance'),
#  ('Jose Manuel', 'Accounting'),
#  ('Jose Manuel', 'Treasury'),
#  ('Jose Manuel', 'Corporate Tax'),
#  ('Jose Manuel', 'Control And Credit'),
#  ('Jose Manuel', 'Shareholder Services'),
#  ('Jose Manuel', 'Benefits'),
#  ('Jose Manuel', 'Manufacturing'),
#  ('Jose Manuel', 'Construction'),
#  ('Jose Manuel', 'Contracting'),
#  ('Jose Manuel', 'Operations'),
#  ('Jose Manuel', 'IT Support'),
#  ('Jose Manuel', 'NOC'),
#  ('Jose Manuel', 'IT Helpdesk'),
#  ('Jose Manuel', 'Government Sales'),
#  ('Jose Manuel', 'Retail Sales'),
#  ('Jose Manuel', 'Recruiting'),
#  ('Jose Manuel', 'Payroll'),
#  ('Luis', '기획부'),
#  ('Luis', '구매부'),
#  ('Luis', 'Administration'),
#  ('Luis', 'Marketing'),
#  ('Luis', 'Purchasing'),
#  ('Luis', 'Human Resources'),
#  ('Luis', 'Shipping'),
#  ('Luis', 'IT'),
#  ('Luis', 'Public Relations'),
#  ('Luis', 'Sales'),
#  ('Luis', 'Executive'),
#  ('Luis', 'Finance'),
#  ('Luis', 'Accounting'),
#  ('Luis', 'Treasury'),
#  ('Luis', 'Corporate Tax'),
#  ('Luis', 'Control And Credit'),
#  ('Luis', 'Shareholder Services'),
#  ('Luis', 'Benefits'),
#  ('Luis', 'Manufacturing'),
#  ('Luis', 'Construction'),
#  ('Luis', 'Contracting'),
#  ('Luis', 'Operations'),
#  ('Luis', 'IT Support'),
#  ('Luis', 'NOC'),
#  ('Luis', 'IT Helpdesk'),
#  ('Luis', 'Government Sales'),
#  ('Luis', 'Retail Sales'),
#  ('Luis', 'Recruiting'),
#  ('Luis', 'Payroll'),
#  ('Den', '기획부'),
#  ('Den', '구매부'),
#  ('Den', 'Administration'),
#  ('Den', 'Marketing'),
#  ('Den', 'Purchasing'),
#  ('Den', 'Human Resources'),
#  ('Den', 'Shipping'),
#  ('Den', 'IT'),
#  ('Den', 'Public Relations'),
#  ('Den', 'Sales'),
#  ('Den', 'Executive'),
#  ('Den', 'Finance'),
#  ('Den', 'Accounting'),
#  ('Den', 'Treasury'),
#  ('Den', 'Corporate Tax'),
#  ('Den', 'Control And Credit'),
#  ('Den', 'Shareholder Services'),
#  ('Den', 'Benefits'),
#  ('Den', 'Manufacturing'),
#  ('Den', 'Construction'),
#  ('Den', 'Contracting'),
#  ('Den', 'Operations'),
#  ('Den', 'IT Support'),
#  ('Den', 'NOC'),
#  ('Den', 'IT Helpdesk'),
#  ('Den', 'Government Sales'),
#  ('Den', 'Retail Sales'),
#  ('Den', 'Recruiting'),
#  ('Den', 'Payroll'),
#  ('Alexander', '기획부'),
#  ('Alexander', '구매부'),
#  ('Alexander', 'Administration'),
#  ('Alexander', 'Marketing'),
#  ('Alexander', 'Purchasing'),
#  ('Alexander', 'Human Resources'),
#  ('Alexander', 'Shipping'),
#  ('Alexander', 'IT'),
#  ('Alexander', 'Public Relations'),
#  ('Alexander', 'Sales'),
#  ('Alexander', 'Executive'),
#  ('Alexander', 'Finance'),
#  ('Alexander', 'Accounting'),
#  ('Alexander', 'Treasury'),
#  ('Alexander', 'Corporate Tax'),
#  ('Alexander', 'Control And Credit'),
#  ('Alexander', 'Shareholder Services'),
#  ('Alexander', 'Benefits'),
#  ('Alexander', 'Manufacturing'),
#  ('Alexander', 'Construction'),
#  ('Alexander', 'Contracting'),
#  ('Alexander', 'Operations'),
#  ('Alexander', 'IT Support'),
#  ('Alexander', 'NOC'),
#  ('Alexander', 'IT Helpdesk'),
#  ('Alexander', 'Government Sales'),
#  ('Alexander', 'Retail Sales'),
#  ('Alexander', 'Recruiting'),
#  ('Alexander', 'Payroll'),
#  ('Shelli', '기획부'),
#  ('Shelli', '구매부'),
#  ('Shelli', 'Administration'),
#  ('Shelli', 'Marketing'),
#  ('Shelli', 'Purchasing'),
#  ('Shelli', 'Human Resources'),
#  ('Shelli', 'Shipping'),
#  ('Shelli', 'IT'),
#  ('Shelli', 'Public Relations'),
#  ('Shelli', 'Sales'),
#  ('Shelli', 'Executive'),
#  ('Shelli', 'Finance'),
#  ('Shelli', 'Accounting'),
#  ('Shelli', 'Treasury'),
#  ('Shelli', 'Corporate Tax'),
#  ('Shelli', 'Control And Credit'),
#  ('Shelli', 'Shareholder Services'),
#  ('Shelli', 'Benefits'),
#  ('Shelli', 'Manufacturing'),
#  ('Shelli', 'Construction'),
#  ('Shelli', 'Contracting'),
#  ('Shelli', 'Operations'),
#  ('Shelli', 'IT Support'),
#  ('Shelli', 'NOC'),
#  ('Shelli', 'IT Helpdesk'),
#  ('Shelli', 'Government Sales'),
#  ('Shelli', 'Retail Sales'),
#  ('Shelli', 'Recruiting'),
#  ('Shelli', 'Payroll'),
#  ('Sigal', '기획부'),
#  ('Sigal', '구매부'),
#  ('Sigal', 'Administration'),
#  ('Sigal', 'Marketing'),
#  ('Sigal', 'Purchasing'),
#  ('Sigal', 'Human Resources'),
#  ('Sigal', 'Shipping'),
#  ('Sigal', 'IT'),
#  ('Sigal', 'Public Relations'),
#  ('Sigal', 'Sales'),
#  ('Sigal', 'Executive'),
#  ('Sigal', 'Finance'),
#  ('Sigal', 'Accounting'),
#  ('Sigal', 'Treasury'),
#  ('Sigal', 'Corporate Tax'),
#  ('Sigal', 'Control And Credit'),
#  ('Sigal', 'Shareholder Services'),
#  ('Sigal', 'Benefits'),
#  ('Sigal', 'Manufacturing'),
#  ('Sigal', 'Construction'),
#  ('Sigal', 'Contracting'),
#  ('Sigal', 'Operations'),
#  ('Sigal', 'IT Support'),
#  ('Sigal', 'NOC'),
#  ('Sigal', 'IT Helpdesk'),
#  ('Sigal', 'Government Sales'),
#  ('Sigal', 'Retail Sales'),
#  ('Sigal', 'Recruiting'),
#  ('Sigal', 'Payroll'),
#  ('Guy', '기획부'),
#  ('Guy', '구매부'),
#  ('Guy', 'Administration'),
#  ('Guy', 'Marketing'),
#  ('Guy', 'Purchasing'),
#  ('Guy', 'Human Resources'),
#  ('Guy', 'Shipping'),
#  ('Guy', 'IT'),
#  ('Guy', 'Public Relations'),
#  ('Guy', 'Sales'),
#  ('Guy', 'Executive'),
#  ('Guy', 'Finance'),
#  ('Guy', 'Accounting'),
#  ('Guy', 'Treasury'),
#  ('Guy', 'Corporate Tax'),
#  ('Guy', 'Control And Credit'),
#  ('Guy', 'Shareholder Services'),
#  ('Guy', 'Benefits'),
#  ('Guy', 'Manufacturing'),
#  ('Guy', 'Construction'),
#  ('Guy', 'Contracting'),
#  ('Guy', 'Operations'),
#  ('Guy', 'IT Support'),
#  ('Guy', 'NOC'),
#  ('Guy', 'IT Helpdesk'),
#  ('Guy', 'Government Sales'),
#  ('Guy', 'Retail Sales'),
#  ('Guy', 'Recruiting'),
#  ('Guy', 'Payroll'),
#  ('Karen', '기획부'),
#  ('Karen', '구매부'),
#  ('Karen', 'Administration'),
#  ('Karen', 'Marketing'),
#  ('Karen', 'Purchasing'),
#  ('Karen', 'Human Resources'),
#  ('Karen', 'Shipping'),
#  ('Karen', 'IT'),
#  ('Karen', 'Public Relations'),
#  ('Karen', 'Sales'),
#  ('Karen', 'Executive'),
#  ('Karen', 'Finance'),
#  ('Karen', 'Accounting'),
#  ('Karen', 'Treasury'),
#  ('Karen', 'Corporate Tax'),
#  ('Karen', 'Control And Credit'),
#  ('Karen', 'Shareholder Services'),
#  ('Karen', 'Benefits'),
#  ('Karen', 'Manufacturing'),
#  ('Karen', 'Construction'),
#  ('Karen', 'Contracting'),
#  ('Karen', 'Operations'),
#  ('Karen', 'IT Support'),
#  ('Karen', 'NOC'),
#  ('Karen', 'IT Helpdesk'),
#  ('Karen', 'Government Sales'),
#  ('Karen', 'Retail Sales'),
#  ('Karen', 'Recruiting'),
#  ('Karen', 'Payroll'),
#  ('Matthew', '기획부'),
#  ('Matthew', '구매부'),
#  ('Matthew', 'Administration'),
#  ('Matthew', 'Marketing'),
#  ('Matthew', 'Purchasing'),
#  ('Matthew', 'Human Resources'),
#  ('Matthew', 'Shipping'),
#  ('Matthew', 'IT'),
#  ('Matthew', 'Public Relations'),
#  ('Matthew', 'Sales'),
#  ('Matthew', 'Executive'),
#  ('Matthew', 'Finance'),
#  ('Matthew', 'Accounting'),
#  ('Matthew', 'Treasury'),
#  ('Matthew', 'Corporate Tax'),
#  ('Matthew', 'Control And Credit'),
#  ('Matthew', 'Shareholder Services'),
#  ('Matthew', 'Benefits'),
#  ('Matthew', 'Manufacturing'),
#  ('Matthew', 'Construction'),
#  ('Matthew', 'Contracting'),
#  ('Matthew', 'Operations'),
#  ('Matthew', 'IT Support'),
#  ('Matthew', 'NOC'),
#  ('Matthew', 'IT Helpdesk'),
#  ('Matthew', 'Government Sales'),
#  ('Matthew', 'Retail Sales'),
#  ('Matthew', 'Recruiting'),
#  ('Matthew', 'Payroll'),
#  ('Adam', '기획부'),
#  ('Adam', '구매부'),
#  ('Adam', 'Administration'),
#  ('Adam', 'Marketing'),
#  ('Adam', 'Purchasing'),
#  ('Adam', 'Human Resources'),
#  ('Adam', 'Shipping'),
#  ('Adam', 'IT'),
#  ('Adam', 'Public Relations'),
#  ('Adam', 'Sales'),
#  ('Adam', 'Executive'),
#  ('Adam', 'Finance'),
#  ('Adam', 'Accounting'),
#  ('Adam', 'Treasury'),
#  ('Adam', 'Corporate Tax'),
#  ('Adam', 'Control And Credit'),
#  ('Adam', 'Shareholder Services'),
#  ('Adam', 'Benefits'),
#  ('Adam', 'Manufacturing'),
#  ('Adam', 'Construction'),
#  ('Adam', 'Contracting'),
#  ('Adam', 'Operations'),
#  ('Adam', 'IT Support'),
#  ('Adam', 'NOC'),
#  ('Adam', 'IT Helpdesk'),
#  ('Adam', 'Government Sales'),
#  ('Adam', 'Retail Sales'),
#  ('Adam', 'Recruiting'),
#  ('Adam', 'Payroll'),
#  ('Payam', '기획부'),
#  ('Payam', '구매부'),
#  ('Payam', 'Administration'),
#  ('Payam', 'Marketing'),
#  ('Payam', 'Purchasing'),
#  ('Payam', 'Human Resources'),
#  ('Payam', 'Shipping'),
#  ('Payam', 'IT'),
#  ('Payam', 'Public Relations'),
#  ('Payam', 'Sales'),
#  ('Payam', 'Executive'),
#  ('Payam', 'Finance'),
#  ('Payam', 'Accounting'),
#  ('Payam', 'Treasury'),
#  ('Payam', 'Corporate Tax'),
#  ('Payam', 'Control And Credit'),
#  ('Payam', 'Shareholder Services'),
#  ('Payam', 'Benefits'),
#  ('Payam', 'Manufacturing'),
#  ('Payam', 'Construction'),
#  ('Payam', 'Contracting'),
#  ('Payam', 'Operations'),
#  ('Payam', 'IT Support'),
#  ('Payam', 'NOC'),
#  ('Payam', 'IT Helpdesk'),
#  ('Payam', 'Government Sales'),
#  ('Payam', 'Retail Sales'),
#  ('Payam', 'Recruiting'),
#  ('Payam', 'Payroll'),
#  ('Shanta', '기획부'),
#  ('Shanta', '구매부'),
#  ('Shanta', 'Administration'),
#  ('Shanta', 'Marketing'),
#  ('Shanta', 'Purchasing'),
#  ('Shanta', 'Human Resources'),
#  ('Shanta', 'Shipping'),
#  ('Shanta', 'IT'),
#  ('Shanta', 'Public Relations'),
#  ('Shanta', 'Sales'),
#  ('Shanta', 'Executive'),
#  ('Shanta', 'Finance'),
#  ('Shanta', 'Accounting'),
#  ('Shanta', 'Treasury'),
#  ('Shanta', 'Corporate Tax'),
#  ('Shanta', 'Control And Credit'),
#  ('Shanta', 'Shareholder Services'),
#  ('Shanta', 'Benefits'),
#  ('Shanta', 'Manufacturing'),
#  ('Shanta', 'Construction'),
#  ('Shanta', 'Contracting'),
#  ('Shanta', 'Operations'),
#  ('Shanta', 'IT Support'),
#  ('Shanta', 'NOC'),
#  ('Shanta', 'IT Helpdesk'),
#  ('Shanta', 'Government Sales'),
#  ('Shanta', 'Retail Sales'),
#  ('Shanta', 'Recruiting'),
#  ('Shanta', 'Payroll'),
#  ('Kevin', '기획부'),
#  ('Kevin', '구매부'),
#  ('Kevin', 'Administration'),
#  ('Kevin', 'Marketing'),
#  ('Kevin', 'Purchasing'),
#  ('Kevin', 'Human Resources'),
#  ('Kevin', 'Shipping'),
#  ('Kevin', 'IT'),
#  ('Kevin', 'Public Relations'),
#  ('Kevin', 'Sales'),
#  ('Kevin', 'Executive'),
#  ('Kevin', 'Finance'),
#  ('Kevin', 'Accounting'),
#  ('Kevin', 'Treasury'),
#  ('Kevin', 'Corporate Tax'),
#  ('Kevin', 'Control And Credit'),
#  ('Kevin', 'Shareholder Services'),
#  ('Kevin', 'Benefits'),
#  ('Kevin', 'Manufacturing'),
#  ('Kevin', 'Construction'),
#  ('Kevin', 'Contracting'),
#  ('Kevin', 'Operations'),
#  ('Kevin', 'IT Support'),
#  ('Kevin', 'NOC'),
#  ('Kevin', 'IT Helpdesk'),
#  ('Kevin', 'Government Sales'),
#  ('Kevin', 'Retail Sales'),
#  ('Kevin', 'Recruiting'),
#  ('Kevin', 'Payroll'),
#  ('Julia', '기획부'),
#  ('Julia', '구매부'),
#  ('Julia', 'Administration'),
#  ('Julia', 'Marketing'),
#  ('Julia', 'Purchasing'),
#  ('Julia', 'Human Resources'),
#  ('Julia', 'Shipping'),
#  ('Julia', 'IT'),
#  ('Julia', 'Public Relations'),
#  ('Julia', 'Sales'),
#  ('Julia', 'Executive'),
#  ('Julia', 'Finance'),
#  ('Julia', 'Accounting'),
#  ('Julia', 'Treasury'),
#  ('Julia', 'Corporate Tax'),
#  ('Julia', 'Control And Credit'),
#  ('Julia', 'Shareholder Services'),
#  ('Julia', 'Benefits'),
#  ('Julia', 'Manufacturing'),
#  ('Julia', 'Construction'),
#  ('Julia', 'Contracting'),
#  ('Julia', 'Operations'),
#  ('Julia', 'IT Support'),
#  ('Julia', 'NOC'),
#  ('Julia', 'IT Helpdesk'),
#  ('Julia', 'Government Sales'),
#  ('Julia', 'Retail Sales'),
#  ('Julia', 'Recruiting'),
#  ('Julia', 'Payroll'),
#  ('Irene', '기획부'),
#  ('Irene', '구매부'),
#  ('Irene', 'Administration'),
#  ('Irene', 'Marketing'),
#  ('Irene', 'Purchasing'),
#  ('Irene', 'Human Resources'),
#  ('Irene', 'Shipping'),
#  ('Irene', 'IT'),
#  ('Irene', 'Public Relations'),
#  ('Irene', 'Sales'),
#  ('Irene', 'Executive'),
#  ('Irene', 'Finance'),
#  ('Irene', 'Accounting'),
#  ('Irene', 'Treasury'),
#  ('Irene', 'Corporate Tax'),
#  ('Irene', 'Control And Credit'),
#  ('Irene', 'Shareholder Services'),
#  ('Irene', 'Benefits'),
#  ('Irene', 'Manufacturing'),
#  ('Irene', 'Construction'),
#  ('Irene', 'Contracting'),
#  ('Irene', 'Operations'),
#  ('Irene', 'IT Support'),
#  ('Irene', 'NOC'),
#  ('Irene', 'IT Helpdesk'),
#  ('Irene', 'Government Sales'),
#  ('Irene', 'Retail Sales'),
#  ('Irene', 'Recruiting'),
#  ('Irene', 'Payroll'),
#  ('James', '기획부'),
#  ('James', '구매부'),
#  ('James', 'Administration'),
#  ('James', 'Marketing'),
#  ('James', 'Purchasing'),
#  ('James', 'Human Resources'),
#  ('James', 'Shipping'),
#  ('James', 'IT'),
#  ('James', 'Public Relations'),
#  ('James', 'Sales'),
#  ('James', 'Executive'),
#  ('James', 'Finance'),
#  ('James', 'Accounting'),
#  ('James', 'Treasury'),
#  ('James', 'Corporate Tax'),
#  ('James', 'Control And Credit'),
#  ('James', 'Shareholder Services'),
#  ('James', 'Benefits'),
#  ('James', 'Manufacturing'),
#  ('James', 'Construction'),
#  ('James', 'Contracting'),
#  ('James', 'Operations'),
#  ('James', 'IT Support'),
#  ('James', 'NOC'),
#  ('James', 'IT Helpdesk'),
#  ('James', 'Government Sales'),
#  ('James', 'Retail Sales'),
#  ('James', 'Recruiting'),
#  ('James', 'Payroll'),
#  ('Steven', '기획부'),
#  ('Steven', '구매부'),
#  ('Steven', 'Administration'),
#  ('Steven', 'Marketing'),
#  ('Steven', 'Purchasing'),
#  ('Steven', 'Human Resources'),
#  ('Steven', 'Shipping'),
#  ('Steven', 'IT'),
#  ('Steven', 'Public Relations'),
#  ('Steven', 'Sales'),
#  ('Steven', 'Executive'),
#  ('Steven', 'Finance'),
#  ('Steven', 'Accounting'),
#  ('Steven', 'Treasury'),
#  ('Steven', 'Corporate Tax'),
#  ('Steven', 'Control And Credit'),
#  ('Steven', 'Shareholder Services'),
#  ('Steven', 'Benefits'),
#  ('Steven', 'Manufacturing'),
#  ('Steven', 'Construction'),
#  ('Steven', 'Contracting'),
#  ('Steven', 'Operations'),
#  ('Steven', 'IT Support'),
#  ('Steven', 'NOC'),
#  ('Steven', 'IT Helpdesk'),
#  ('Steven', 'Government Sales'),
#  ('Steven', 'Retail Sales'),
#  ('Steven', 'Recruiting'),
#  ('Steven', 'Payroll'),
#  ('Laura', '기획부'),
#  ('Laura', '구매부'),
#  ('Laura', 'Administration'),
#  ('Laura', 'Marketing'),
#  ('Laura', 'Purchasing'),
#  ('Laura', 'Human Resources'),
#  ('Laura', 'Shipping'),
#  ('Laura', 'IT'),
#  ('Laura', 'Public Relations'),
#  ('Laura', 'Sales'),
#  ('Laura', 'Executive'),
#  ('Laura', 'Finance'),
#  ('Laura', 'Accounting'),
#  ('Laura', 'Treasury'),
#  ('Laura', 'Corporate Tax'),
#  ('Laura', 'Control And Credit'),
#  ('Laura', 'Shareholder Services'),
#  ('Laura', 'Benefits'),
#  ('Laura', 'Manufacturing'),
#  ('Laura', 'Construction'),
#  ('Laura', 'Contracting'),
#  ('Laura', 'Operations'),
#  ('Laura', 'IT Support'),
#  ('Laura', 'NOC'),
#  ('Laura', 'IT Helpdesk'),
#  ('Laura', 'Government Sales'),
#  ('Laura', 'Retail Sales'),
#  ('Laura', 'Recruiting'),
#  ('Laura', 'Payroll'),
#  ('Mozhe', '기획부'),
#  ('Mozhe', '구매부'),
#  ('Mozhe', 'Administration'),
#  ('Mozhe', 'Marketing'),
#  ('Mozhe', 'Purchasing'),
#  ('Mozhe', 'Human Resources'),
#  ('Mozhe', 'Shipping'),
#  ('Mozhe', 'IT'),
#  ('Mozhe', 'Public Relations'),
#  ('Mozhe', 'Sales'),
#  ('Mozhe', 'Executive'),
#  ('Mozhe', 'Finance'),
#  ('Mozhe', 'Accounting'),
#  ('Mozhe', 'Treasury'),
#  ('Mozhe', 'Corporate Tax'),
#  ('Mozhe', 'Control And Credit'),
#  ('Mozhe', 'Shareholder Services'),
#  ('Mozhe', 'Benefits'),
#  ('Mozhe', 'Manufacturing'),
#  ('Mozhe', 'Construction'),
#  ('Mozhe', 'Contracting'),
#  ('Mozhe', 'Operations'),
#  ('Mozhe', 'IT Support'),
#  ('Mozhe', 'NOC'),
#  ('Mozhe', 'IT Helpdesk'),
#  ('Mozhe', 'Government Sales'),
#  ('Mozhe', 'Retail Sales'),
#  ('Mozhe', 'Recruiting'),
#  ('Mozhe', 'Payroll'),
#  ('James', '기획부'),
#  ('James', '구매부'),
#  ('James', 'Administration'),
#  ('James', 'Marketing'),
#  ('James', 'Purchasing'),
#  ('James', 'Human Resources'),
#  ('James', 'Shipping'),
#  ('James', 'IT'),
#  ('James', 'Public Relations'),
#  ('James', 'Sales'),
#  ('James', 'Executive'),
#  ('James', 'Finance'),
#  ('James', 'Accounting'),
#  ('James', 'Treasury'),
#  ('James', 'Corporate Tax'),
#  ('James', 'Control And Credit'),
#  ('James', 'Shareholder Services'),
#  ('James', 'Benefits'),
#  ('James', 'Manufacturing'),
#  ('James', 'Construction'),
#  ('James', 'Contracting'),
#  ('James', 'Operations'),
#  ('James', 'IT Support'),
#  ('James', 'NOC'),
#  ('James', 'IT Helpdesk'),
#  ('James', 'Government Sales'),
#  ('James', 'Retail Sales'),
#  ('James', 'Recruiting'),
#  ('James', 'Payroll'),
#  ('TJ', '기획부'),
#  ('TJ', '구매부'),
#  ('TJ', 'Administration'),
#  ('TJ', 'Marketing'),
#  ('TJ', 'Purchasing'),
#  ('TJ', 'Human Resources'),
#  ('TJ', 'Shipping'),
#  ('TJ', 'IT'),
#  ('TJ', 'Public Relations'),
#  ('TJ', 'Sales'),
#  ('TJ', 'Executive'),
#  ('TJ', 'Finance'),
#  ('TJ', 'Accounting'),
#  ('TJ', 'Treasury'),
#  ('TJ', 'Corporate Tax'),
#  ('TJ', 'Control And Credit'),
#  ('TJ', 'Shareholder Services'),
#  ('TJ', 'Benefits'),
#  ('TJ', 'Manufacturing'),
#  ('TJ', 'Construction'),
#  ('TJ', 'Contracting'),
#  ('TJ', 'Operations'),
#  ('TJ', 'IT Support'),
#  ('TJ', 'NOC'),
#  ('TJ', 'IT Helpdesk'),
#  ('TJ', 'Government Sales'),
#  ('TJ', 'Retail Sales'),
#  ('TJ', 'Recruiting'),
#  ('TJ', 'Payroll'),
#  ('Jason', '기획부'),
#  ('Jason', '구매부'),
#  ('Jason', 'Administration'),
#  ('Jason', 'Marketing'),
#  ('Jason', 'Purchasing'),
#  ('Jason', 'Human Resources'),
#  ('Jason', 'Shipping'),
#  ('Jason', 'IT'),
#  ('Jason', 'Public Relations'),
#  ('Jason', 'Sales'),
#  ('Jason', 'Executive'),
#  ('Jason', 'Finance'),
#  ('Jason', 'Accounting'),
#  ('Jason', 'Treasury'),
#  ('Jason', 'Corporate Tax'),
#  ('Jason', 'Control And Credit'),
#  ('Jason', 'Shareholder Services'),
#  ('Jason', 'Benefits'),
#  ('Jason', 'Manufacturing'),
#  ('Jason', 'Construction'),
#  ('Jason', 'Contracting'),
#  ('Jason', 'Operations'),
#  ('Jason', 'IT Support'),
#  ('Jason', 'NOC'),
#  ('Jason', 'IT Helpdesk'),
#  ('Jason', 'Government Sales'),
#  ('Jason', 'Retail Sales'),
#  ('Jason', 'Recruiting'),
#  ('Jason', 'Payroll'),
#  ('Michael', '기획부'),
#  ('Michael', '구매부'),
#  ('Michael', 'Administration'),
#  ('Michael', 'Marketing'),
#  ('Michael', 'Purchasing'),
#  ('Michael', 'Human Resources'),
#  ('Michael', 'Shipping'),
#  ('Michael', 'IT'),
#  ('Michael', 'Public Relations'),
#  ('Michael', 'Sales'),
#  ('Michael', 'Executive'),
#  ('Michael', 'Finance'),
#  ('Michael', 'Accounting'),
#  ('Michael', 'Treasury'),
#  ('Michael', 'Corporate Tax'),
#  ('Michael', 'Control And Credit'),
#  ('Michael', 'Shareholder Services'),
#  ('Michael', 'Benefits'),
#  ('Michael', 'Manufacturing'),
#  ('Michael', 'Construction'),
#  ('Michael', 'Contracting'),
#  ('Michael', 'Operations'),
#  ('Michael', 'IT Support'),
#  ('Michael', 'NOC'),
#  ('Michael', 'IT Helpdesk'),
#  ('Michael', 'Government Sales'),
#  ('Michael', 'Retail Sales'),
#  ('Michael', 'Recruiting'),
#  ('Michael', 'Payroll'),
#  ('Ki', '기획부'),
#  ('Ki', '구매부'),
#  ('Ki', 'Administration'),
#  ('Ki', 'Marketing'),
#  ('Ki', 'Purchasing'),
#  ('Ki', 'Human Resources'),
#  ('Ki', 'Shipping'),
#  ('Ki', 'IT'),
#  ('Ki', 'Public Relations'),
#  ('Ki', 'Sales'),
#  ('Ki', 'Executive'),
#  ('Ki', 'Finance'),
#  ('Ki', 'Accounting'),
#  ('Ki', 'Treasury'),
#  ('Ki', 'Corporate Tax'),
#  ('Ki', 'Control And Credit'),
#  ('Ki', 'Shareholder Services'),
#  ('Ki', 'Benefits'),
#  ('Ki', 'Manufacturing'),
#  ('Ki', 'Construction'),
#  ('Ki', 'Contracting'),
#  ('Ki', 'Operations'),
#  ('Ki', 'IT Support'),
#  ('Ki', 'NOC'),
#  ('Ki', 'IT Helpdesk'),
#  ('Ki', 'Government Sales'),
#  ('Ki', 'Retail Sales'),
#  ('Ki', 'Recruiting'),
#  ('Ki', 'Payroll'),
#  ('Hazel', '기획부'),
#  ('Hazel', '구매부'),
#  ('Hazel', 'Administration'),
#  ('Hazel', 'Marketing'),
#  ('Hazel', 'Purchasing'),
#  ('Hazel', 'Human Resources'),
#  ('Hazel', 'Shipping'),
#  ('Hazel', 'IT'),
#  ('Hazel', 'Public Relations'),
#  ('Hazel', 'Sales'),
#  ('Hazel', 'Executive'),
#  ('Hazel', 'Finance'),
#  ('Hazel', 'Accounting'),
#  ('Hazel', 'Treasury'),
#  ('Hazel', 'Corporate Tax'),
#  ('Hazel', 'Control And Credit'),
#  ('Hazel', 'Shareholder Services'),
#  ('Hazel', 'Benefits'),
#  ('Hazel', 'Manufacturing'),
#  ('Hazel', 'Construction'),
#  ('Hazel', 'Contracting'),
#  ('Hazel', 'Operations'),
#  ('Hazel', 'IT Support'),
#  ('Hazel', 'NOC'),
#  ('Hazel', 'IT Helpdesk'),
#  ('Hazel', 'Government Sales'),
#  ('Hazel', 'Retail Sales'),
#  ('Hazel', 'Recruiting'),
#  ('Hazel', 'Payroll'),
#  ('Renske', '기획부'),
#  ('Renske', '구매부'),
#  ('Renske', 'Administration'),
#  ('Renske', 'Marketing'),
#  ('Renske', 'Purchasing'),
#  ('Renske', 'Human Resources'),
#  ('Renske', 'Shipping'),
#  ('Renske', 'IT'),
#  ('Renske', 'Public Relations'),
#  ('Renske', 'Sales'),
#  ('Renske', 'Executive'),
#  ('Renske', 'Finance'),
#  ('Renske', 'Accounting'),
#  ('Renske', 'Treasury'),
#  ('Renske', 'Corporate Tax'),
#  ('Renske', 'Control And Credit'),
#  ('Renske', 'Shareholder Services'),
#  ('Renske', 'Benefits'),
#  ('Renske', 'Manufacturing'),
#  ('Renske', 'Construction'),
#  ('Renske', 'Contracting'),
#  ('Renske', 'Operations'),
#  ('Renske', 'IT Support'),
#  ('Renske', 'NOC'),
#  ('Renske', 'IT Helpdesk'),
#  ('Renske', 'Government Sales'),
#  ('Renske', 'Retail Sales'),
#  ('Renske', 'Recruiting'),
#  ('Renske', 'Payroll'),
#  ('Stephen', '기획부'),
#  ('Stephen', '구매부'),
#  ('Stephen', 'Administration'),
#  ('Stephen', 'Marketing'),
#  ('Stephen', 'Purchasing'),
#  ('Stephen', 'Human Resources'),
#  ('Stephen', 'Shipping'),
#  ('Stephen', 'IT'),
#  ('Stephen', 'Public Relations'),
#  ('Stephen', 'Sales'),
#  ('Stephen', 'Executive'),
#  ('Stephen', 'Finance'),
#  ('Stephen', 'Accounting'),
#  ('Stephen', 'Treasury'),
#  ('Stephen', 'Corporate Tax'),
#  ('Stephen', 'Control And Credit'),
#  ('Stephen', 'Shareholder Services'),
#  ('Stephen', 'Benefits'),
#  ('Stephen', 'Manufacturing'),
#  ('Stephen', 'Construction'),
#  ('Stephen', 'Contracting'),
#  ('Stephen', 'Operations'),
#  ('Stephen', 'IT Support'),
#  ('Stephen', 'NOC'),
#  ('Stephen', 'IT Helpdesk'),
#  ('Stephen', 'Government Sales'),
#  ('Stephen', 'Retail Sales'),
#  ('Stephen', 'Recruiting'),
#  ('Stephen', 'Payroll'),
#  ('John', '기획부'),
#  ('John', '구매부'),
#  ('John', 'Administration'),
#  ('John', 'Marketing'),
#  ('John', 'Purchasing'),
#  ('John', 'Human Resources'),
#  ('John', 'Shipping'),
#  ('John', 'IT'),
#  ('John', 'Public Relations'),
#  ('John', 'Sales'),
#  ('John', 'Executive'),
#  ('John', 'Finance'),
#  ('John', 'Accounting'),
#  ('John', 'Treasury'),
#  ('John', 'Corporate Tax'),
#  ('John', 'Control And Credit'),
#  ('John', 'Shareholder Services'),
#  ('John', 'Benefits'),
#  ('John', 'Manufacturing'),
#  ('John', 'Construction'),
#  ('John', 'Contracting'),
#  ('John', 'Operations'),
#  ('John', 'IT Support'),
#  ('John', 'NOC'),
#  ('John', 'IT Helpdesk'),
#  ('John', 'Government Sales'),
#  ('John', 'Retail Sales'),
#  ('John', 'Recruiting'),
#  ('John', 'Payroll'),
#  ('Joshua', '기획부'),
#  ('Joshua', '구매부'),
#  ('Joshua', 'Administration'),
#  ('Joshua', 'Marketing'),
#  ('Joshua', 'Purchasing'),
#  ('Joshua', 'Human Resources'),
#  ('Joshua', 'Shipping'),
#  ('Joshua', 'IT'),
#  ('Joshua', 'Public Relations'),
#  ('Joshua', 'Sales'),
#  ('Joshua', 'Executive'),
#  ('Joshua', 'Finance'),
#  ('Joshua', 'Accounting'),
#  ('Joshua', 'Treasury'),
#  ('Joshua', 'Corporate Tax'),
#  ('Joshua', 'Control And Credit'),
#  ('Joshua', 'Shareholder Services'),
#  ('Joshua', 'Benefits'),
#  ('Joshua', 'Manufacturing'),
#  ('Joshua', 'Construction'),
#  ('Joshua', 'Contracting'),
#  ('Joshua', 'Operations'),
#  ('Joshua', 'IT Support'),
#  ('Joshua', 'NOC'),
#  ('Joshua', 'IT Helpdesk'),
#  ('Joshua', 'Government Sales'),
#  ('Joshua', 'Retail Sales'),
#  ('Joshua', 'Recruiting'),
#  ('Joshua', 'Payroll'),
#  ('Trenna', '기획부'),
#  ('Trenna', '구매부'),
#  ('Trenna', 'Administration'),
#  ('Trenna', 'Marketing'),
#  ('Trenna', 'Purchasing'),
#  ('Trenna', 'Human Resources'),
#  ('Trenna', 'Shipping'),
#  ('Trenna', 'IT'),
#  ('Trenna', 'Public Relations'),
#  ('Trenna', 'Sales'),
#  ('Trenna', 'Executive'),
#  ('Trenna', 'Finance'),
#  ('Trenna', 'Accounting'),
#  ('Trenna', 'Treasury'),
#  ('Trenna', 'Corporate Tax'),
#  ('Trenna', 'Control And Credit'),
#  ('Trenna', 'Shareholder Services'),
#  ('Trenna', 'Benefits'),
#  ('Trenna', 'Manufacturing'),
#  ('Trenna', 'Construction'),
#  ('Trenna', 'Contracting'),
#  ('Trenna', 'Operations'),
#  ('Trenna', 'IT Support'),
#  ('Trenna', 'NOC'),
#  ('Trenna', 'IT Helpdesk'),
#  ('Trenna', 'Government Sales'),
#  ('Trenna', 'Retail Sales'),
#  ('Trenna', 'Recruiting'),
#  ('Trenna', 'Payroll'),
#  ('Curtis', '기획부'),
#  ('Curtis', '구매부'),
#  ('Curtis', 'Administration'),
#  ('Curtis', 'Marketing'),
#  ('Curtis', 'Purchasing'),
#  ('Curtis', 'Human Resources'),
#  ('Curtis', 'Shipping'),
#  ('Curtis', 'IT'),
#  ('Curtis', 'Public Relations'),
#  ('Curtis', 'Sales'),
#  ('Curtis', 'Executive'),
#  ('Curtis', 'Finance'),
#  ('Curtis', 'Accounting'),
#  ('Curtis', 'Treasury'),
#  ('Curtis', 'Corporate Tax'),
#  ('Curtis', 'Control And Credit'),
#  ('Curtis', 'Shareholder Services'),
#  ('Curtis', 'Benefits'),
#  ('Curtis', 'Manufacturing'),
#  ('Curtis', 'Construction'),
#  ('Curtis', 'Contracting'),
#  ('Curtis', 'Operations'),
#  ('Curtis', 'IT Support'),
#  ('Curtis', 'NOC'),
#  ('Curtis', 'IT Helpdesk'),
#  ('Curtis', 'Government Sales'),
#  ('Curtis', 'Retail Sales'),
#  ('Curtis', 'Recruiting'),
#  ('Curtis', 'Payroll'),
#  ('Randall', '기획부'),
#  ('Randall', '구매부'),
#  ('Randall', 'Administration'),
#  ('Randall', 'Marketing'),
#  ('Randall', 'Purchasing'),
#  ('Randall', 'Human Resources'),
#  ('Randall', 'Shipping'),
#  ('Randall', 'IT'),
#  ('Randall', 'Public Relations'),
#  ('Randall', 'Sales'),
#  ('Randall', 'Executive'),
#  ('Randall', 'Finance'),
#  ('Randall', 'Accounting'),
#  ('Randall', 'Treasury'),
#  ('Randall', 'Corporate Tax'),
#  ('Randall', 'Control And Credit'),
#  ('Randall', 'Shareholder Services'),
#  ('Randall', 'Benefits'),
#  ('Randall', 'Manufacturing'),
#  ('Randall', 'Construction'),
#  ('Randall', 'Contracting'),
#  ('Randall', 'Operations'),
#  ('Randall', 'IT Support'),
#  ('Randall', 'NOC'),
#  ('Randall', 'IT Helpdesk'),
#  ('Randall', 'Government Sales'),
#  ('Randall', 'Retail Sales'),
#  ('Randall', 'Recruiting'),
#  ('Randall', 'Payroll'),
#  ('Peter', '기획부'),
#  ('Peter', '구매부'),
#  ('Peter', 'Administration'),
#  ('Peter', 'Marketing'),
#  ('Peter', 'Purchasing'),
#  ('Peter', 'Human Resources'),
#  ('Peter', 'Shipping'),
#  ('Peter', 'IT'),
#  ('Peter', 'Public Relations'),
#  ('Peter', 'Sales'),
#  ('Peter', 'Executive'),
#  ('Peter', 'Finance'),
#  ('Peter', 'Accounting'),
#  ('Peter', 'Treasury'),
#  ('Peter', 'Corporate Tax'),
#  ('Peter', 'Control And Credit'),
#  ('Peter', 'Shareholder Services'),
#  ('Peter', 'Benefits'),
#  ('Peter', 'Manufacturing'),
#  ('Peter', 'Construction'),
#  ('Peter', 'Contracting'),
#  ('Peter', 'Operations'),
#  ('Peter', 'IT Support'),
#  ('Peter', 'NOC'),
#  ('Peter', 'IT Helpdesk'),
#  ('Peter', 'Government Sales'),
#  ('Peter', 'Retail Sales'),
#  ('Peter', 'Recruiting'),
#  ('Peter', 'Payroll'),
#  ('John', '기획부'),
#  ('John', '구매부'),
#  ('John', 'Administration'),
#  ('John', 'Marketing'),
#  ('John', 'Purchasing'),
#  ('John', 'Human Resources'),
#  ('John', 'Shipping'),
#  ('John', 'IT'),
#  ('John', 'Public Relations'),
#  ('John', 'Sales'),
#  ('John', 'Executive'),
#  ('John', 'Finance'),
#  ('John', 'Accounting'),
#  ('John', 'Treasury'),
#  ('John', 'Corporate Tax'),
#  ('John', 'Control And Credit'),
#  ('John', 'Shareholder Services'),
#  ('John', 'Benefits'),
#  ('John', 'Manufacturing'),
#  ('John', 'Construction'),
#  ('John', 'Contracting'),
#  ('John', 'Operations'),
#  ('John', 'IT Support'),
#  ('John', 'NOC'),
#  ('John', 'IT Helpdesk'),
#  ('John', 'Government Sales'),
#  ('John', 'Retail Sales'),
#  ('John', 'Recruiting'),
#  ('John', 'Payroll'),
#  ('Karen', '기획부'),
#  ('Karen', '구매부'),
#  ('Karen', 'Administration'),
#  ('Karen', 'Marketing'),
#  ('Karen', 'Purchasing'),
#  ('Karen', 'Human Resources'),
#  ('Karen', 'Shipping'),
#  ('Karen', 'IT'),
#  ('Karen', 'Public Relations'),
#  ('Karen', 'Sales'),
#  ('Karen', 'Executive'),
#  ('Karen', 'Finance'),
#  ('Karen', 'Accounting'),
#  ('Karen', 'Treasury'),
#  ('Karen', 'Corporate Tax'),
#  ('Karen', 'Control And Credit'),
#  ('Karen', 'Shareholder Services'),
#  ('Karen', 'Benefits'),
#  ('Karen', 'Manufacturing'),
#  ('Karen', 'Construction'),
#  ('Karen', 'Contracting'),
#  ('Karen', 'Operations'),
#  ('Karen', 'IT Support'),
#  ('Karen', 'NOC'),
#  ('Karen', 'IT Helpdesk'),
#  ('Karen', 'Government Sales'),
#  ('Karen', 'Retail Sales'),
#  ('Karen', 'Recruiting'),
#  ('Karen', 'Payroll'),
#  ('Alberto', '기획부'),
#  ('Alberto', '구매부'),
#  ('Alberto', 'Administration'),
#  ('Alberto', 'Marketing'),
#  ('Alberto', 'Purchasing'),
#  ('Alberto', 'Human Resources'),
#  ('Alberto', 'Shipping'),
#  ('Alberto', 'IT'),
#  ('Alberto', 'Public Relations'),
#  ('Alberto', 'Sales'),
#  ('Alberto', 'Executive'),
#  ('Alberto', 'Finance'),
#  ('Alberto', 'Accounting'),
#  ('Alberto', 'Treasury'),
#  ('Alberto', 'Corporate Tax'),
#  ('Alberto', 'Control And Credit'),
#  ('Alberto', 'Shareholder Services'),
#  ('Alberto', 'Benefits'),
#  ('Alberto', 'Manufacturing'),
#  ('Alberto', 'Construction'),
#  ('Alberto', 'Contracting'),
#  ('Alberto', 'Operations'),
#  ('Alberto', 'IT Support'),
#  ('Alberto', 'NOC'),
#  ('Alberto', 'IT Helpdesk'),
#  ('Alberto', 'Government Sales'),
#  ('Alberto', 'Retail Sales'),
#  ('Alberto', 'Recruiting'),
#  ('Alberto', 'Payroll'),
#  ('Gerald', '기획부'),
#  ('Gerald', '구매부'),
#  ('Gerald', 'Administration'),
#  ('Gerald', 'Marketing'),
#  ('Gerald', 'Purchasing'),
#  ('Gerald', 'Human Resources'),
#  ('Gerald', 'Shipping'),
#  ('Gerald', 'IT'),
#  ('Gerald', 'Public Relations'),
#  ('Gerald', 'Sales'),
#  ('Gerald', 'Executive'),
#  ('Gerald', 'Finance'),
#  ('Gerald', 'Accounting'),
#  ('Gerald', 'Treasury'),
#  ('Gerald', 'Corporate Tax'),
#  ('Gerald', 'Control And Credit'),
#  ('Gerald', 'Shareholder Services'),
#  ('Gerald', 'Benefits'),
#  ('Gerald', 'Manufacturing'),
#  ('Gerald', 'Construction'),
#  ('Gerald', 'Contracting'),
#  ('Gerald', 'Operations'),
#  ('Gerald', 'IT Support'),
#  ('Gerald', 'NOC'),
#  ('Gerald', 'IT Helpdesk'),
#  ('Gerald', 'Government Sales'),
#  ('Gerald', 'Retail Sales'),
#  ('Gerald', 'Recruiting'),
#  ('Gerald', 'Payroll'),
#  ('Eleni', '기획부'),
#  ('Eleni', '구매부'),
#  ('Eleni', 'Administration'),
#  ('Eleni', 'Marketing'),
#  ('Eleni', 'Purchasing'),
#  ('Eleni', 'Human Resources'),
#  ('Eleni', 'Shipping'),
#  ('Eleni', 'IT'),
#  ('Eleni', 'Public Relations'),
#  ('Eleni', 'Sales'),
#  ('Eleni', 'Executive'),
#  ('Eleni', 'Finance'),
#  ('Eleni', 'Accounting'),
#  ('Eleni', 'Treasury'),
#  ('Eleni', 'Corporate Tax'),
#  ('Eleni', 'Control And Credit'),
#  ('Eleni', 'Shareholder Services'),
#  ('Eleni', 'Benefits'),
#  ('Eleni', 'Manufacturing'),
#  ('Eleni', 'Construction'),
#  ('Eleni', 'Contracting'),
#  ('Eleni', 'Operations'),
#  ('Eleni', 'IT Support'),
#  ('Eleni', 'NOC'),
#  ('Eleni', 'IT Helpdesk'),
#  ('Eleni', 'Government Sales'),
#  ('Eleni', 'Retail Sales'),
#  ('Eleni', 'Recruiting'),
#  ('Eleni', 'Payroll'),
#  ('Peter', '기획부'),
#  ('Peter', '구매부'),
#  ('Peter', 'Administration'),
#  ('Peter', 'Marketing'),
#  ('Peter', 'Purchasing'),
#  ('Peter', 'Human Resources'),
#  ('Peter', 'Shipping'),
#  ('Peter', 'IT'),
#  ('Peter', 'Public Relations'),
#  ('Peter', 'Sales'),
#  ('Peter', 'Executive'),
#  ('Peter', 'Finance'),
#  ('Peter', 'Accounting'),
#  ('Peter', 'Treasury'),
#  ('Peter', 'Corporate Tax'),
#  ('Peter', 'Control And Credit'),
#  ('Peter', 'Shareholder Services'),
#  ('Peter', 'Benefits'),
#  ('Peter', 'Manufacturing'),
#  ('Peter', 'Construction'),
#  ('Peter', 'Contracting'),
#  ('Peter', 'Operations'),
#  ('Peter', 'IT Support'),
#  ('Peter', 'NOC'),
#  ('Peter', 'IT Helpdesk'),
#  ('Peter', 'Government Sales'),
#  ('Peter', 'Retail Sales'),
#  ('Peter', 'Recruiting'),
#  ('Peter', 'Payroll'),
#  ('David', '기획부'),
#  ('David', '구매부'),
#  ('David', 'Administration'),
#  ('David', 'Marketing'),
#  ('David', 'Purchasing'),
#  ('David', 'Human Resources'),
#  ('David', 'Shipping'),
#  ('David', 'IT'),
#  ('David', 'Public Relations'),
#  ('David', 'Sales'),
#  ('David', 'Executive'),
#  ('David', 'Finance'),
#  ('David', 'Accounting'),
#  ('David', 'Treasury'),
#  ('David', 'Corporate Tax'),
#  ('David', 'Control And Credit'),
#  ('David', 'Shareholder Services'),
#  ('David', 'Benefits'),
#  ('David', 'Manufacturing'),
#  ('David', 'Construction'),
#  ('David', 'Contracting'),
#  ('David', 'Operations'),
#  ('David', 'IT Support'),
#  ('David', 'NOC'),
#  ('David', 'IT Helpdesk'),
#  ('David', 'Government Sales'),
#  ('David', 'Retail Sales'),
#  ('David', 'Recruiting'),
#  ('David', 'Payroll'),
#  ('Peter', '기획부'),
#  ('Peter', '구매부'),
#  ('Peter', 'Administration'),
#  ('Peter', 'Marketing'),
#  ('Peter', 'Purchasing'),
#  ('Peter', 'Human Resources'),
#  ('Peter', 'Shipping'),
#  ('Peter', 'IT'),
#  ('Peter', 'Public Relations'),
#  ('Peter', 'Sales'),
#  ('Peter', 'Executive'),
#  ('Peter', 'Finance'),
#  ('Peter', 'Accounting'),
#  ('Peter', 'Treasury'),
#  ('Peter', 'Corporate Tax'),
#  ('Peter', 'Control And Credit'),
#  ('Peter', 'Shareholder Services'),
#  ('Peter', 'Benefits'),
#  ('Peter', 'Manufacturing'),
#  ('Peter', 'Construction'),
#  ('Peter', 'Contracting'),
#  ('Peter', 'Operations'),
#  ('Peter', 'IT Support'),
#  ('Peter', 'NOC'),
#  ('Peter', 'IT Helpdesk'),
#  ('Peter', 'Government Sales'),
#  ('Peter', 'Retail Sales'),
#  ('Peter', 'Recruiting'),
#  ('Peter', 'Payroll'),
#  ('Christopher', '기획부'),
#  ('Christopher', '구매부'),
#  ('Christopher', 'Administration'),
#  ('Christopher', 'Marketing'),
#  ('Christopher', 'Purchasing'),
#  ('Christopher', 'Human Resources'),
#  ('Christopher', 'Shipping'),
#  ('Christopher', 'IT'),
#  ('Christopher', 'Public Relations'),
#  ('Christopher', 'Sales'),
#  ('Christopher', 'Executive'),
#  ('Christopher', 'Finance'),
#  ('Christopher', 'Accounting'),
#  ('Christopher', 'Treasury'),
#  ('Christopher', 'Corporate Tax'),
#  ('Christopher', 'Control And Credit'),
#  ('Christopher', 'Shareholder Services'),
#  ('Christopher', 'Benefits'),
#  ('Christopher', 'Manufacturing'),
#  ('Christopher', 'Construction'),
#  ('Christopher', 'Contracting'),
#  ('Christopher', 'Operations'),
#  ('Christopher', 'IT Support'),
#  ('Christopher', 'NOC'),
#  ('Christopher', 'IT Helpdesk'),
#  ('Christopher', 'Government Sales'),
#  ('Christopher', 'Retail Sales'),
#  ('Christopher', 'Recruiting'),
#  ('Christopher', 'Payroll'),
#  ('Nanette', '기획부'),
#  ('Nanette', '구매부'),
#  ('Nanette', 'Administration'),
#  ('Nanette', 'Marketing'),
#  ('Nanette', 'Purchasing'),
#  ('Nanette', 'Human Resources'),
#  ('Nanette', 'Shipping'),
#  ('Nanette', 'IT'),
#  ('Nanette', 'Public Relations'),
#  ('Nanette', 'Sales'),
#  ('Nanette', 'Executive'),
#  ('Nanette', 'Finance'),
#  ('Nanette', 'Accounting'),
#  ('Nanette', 'Treasury'),
#  ('Nanette', 'Corporate Tax'),
#  ('Nanette', 'Control And Credit'),
#  ('Nanette', 'Shareholder Services'),
#  ('Nanette', 'Benefits'),
#  ('Nanette', 'Manufacturing'),
#  ('Nanette', 'Construction'),
#  ('Nanette', 'Contracting'),
#  ('Nanette', 'Operations'),
#  ('Nanette', 'IT Support'),
#  ('Nanette', 'NOC'),
#  ('Nanette', 'IT Helpdesk'),
#  ('Nanette', 'Government Sales'),
#  ('Nanette', 'Retail Sales'),
#  ('Nanette', 'Recruiting'),
#  ('Nanette', 'Payroll'),
#  ('Oliver', '기획부'),
#  ('Oliver', '구매부'),
#  ('Oliver', 'Administration'),
#  ('Oliver', 'Marketing'),
#  ('Oliver', 'Purchasing'),
#  ('Oliver', 'Human Resources'),
#  ('Oliver', 'Shipping'),
#  ('Oliver', 'IT'),
#  ('Oliver', 'Public Relations'),
#  ('Oliver', 'Sales'),
#  ('Oliver', 'Executive'),
#  ('Oliver', 'Finance'),
#  ('Oliver', 'Accounting'),
#  ('Oliver', 'Treasury'),
#  ('Oliver', 'Corporate Tax'),
#  ('Oliver', 'Control And Credit'),
#  ('Oliver', 'Shareholder Services'),
#  ('Oliver', 'Benefits'),
#  ('Oliver', 'Manufacturing'),
#  ('Oliver', 'Construction'),
#  ('Oliver', 'Contracting'),
#  ('Oliver', 'Operations'),
#  ('Oliver', 'IT Support'),
#  ('Oliver', 'NOC'),
#  ('Oliver', 'IT Helpdesk'),
#  ('Oliver', 'Government Sales'),
#  ('Oliver', 'Retail Sales'),
#  ('Oliver', 'Recruiting'),
#  ('Oliver', 'Payroll'),
#  ('Janette', '기획부'),
#  ('Janette', '구매부'),
#  ('Janette', 'Administration'),
#  ('Janette', 'Marketing'),
#  ('Janette', 'Purchasing'),
#  ('Janette', 'Human Resources'),
#  ('Janette', 'Shipping'),
#  ('Janette', 'IT'),
#  ('Janette', 'Public Relations'),
#  ('Janette', 'Sales'),
#  ('Janette', 'Executive'),
#  ('Janette', 'Finance'),
#  ('Janette', 'Accounting'),
#  ('Janette', 'Treasury'),
#  ('Janette', 'Corporate Tax'),
#  ('Janette', 'Control And Credit'),
#  ('Janette', 'Shareholder Services'),
#  ('Janette', 'Benefits'),
#  ('Janette', 'Manufacturing'),
#  ('Janette', 'Construction'),
#  ('Janette', 'Contracting'),
#  ('Janette', 'Operations'),
#  ('Janette', 'IT Support'),
#  ('Janette', 'NOC'),
#  ('Janette', 'IT Helpdesk'),
#  ('Janette', 'Government Sales'),
#  ('Janette', 'Retail Sales'),
#  ('Janette', 'Recruiting'),
#  ('Janette', 'Payroll'),
#  ('Patrick', '기획부'),
#  ('Patrick', '구매부'),
#  ('Patrick', 'Administration'),
#  ('Patrick', 'Marketing'),
#  ('Patrick', 'Purchasing'),
#  ('Patrick', 'Human Resources'),
#  ('Patrick', 'Shipping'),
#  ('Patrick', 'IT'),
#  ('Patrick', 'Public Relations'),
#  ('Patrick', 'Sales'),
#  ('Patrick', 'Executive'),
#  ('Patrick', 'Finance'),
#  ('Patrick', 'Accounting'),
#  ('Patrick', 'Treasury'),
#  ('Patrick', 'Corporate Tax'),
#  ('Patrick', 'Control And Credit'),
#  ('Patrick', 'Shareholder Services'),
#  ('Patrick', 'Benefits'),
#  ('Patrick', 'Manufacturing'),
#  ('Patrick', 'Construction'),
#  ('Patrick', 'Contracting'),
#  ('Patrick', 'Operations'),
#  ('Patrick', 'IT Support'),
#  ('Patrick', 'NOC'),
#  ('Patrick', 'IT Helpdesk'),
#  ('Patrick', 'Government Sales'),
#  ('Patrick', 'Retail Sales'),
#  ('Patrick', 'Recruiting'),
#  ('Patrick', 'Payroll'),
#  ('Allan', '기획부'),
#  ('Allan', '구매부'),
#  ('Allan', 'Administration'),
#  ('Allan', 'Marketing'),
#  ('Allan', 'Purchasing'),
#  ('Allan', 'Human Resources'),
#  ('Allan', 'Shipping'),
#  ('Allan', 'IT'),
#  ('Allan', 'Public Relations'),
#  ('Allan', 'Sales'),
#  ('Allan', 'Executive'),
#  ('Allan', 'Finance'),
#  ('Allan', 'Accounting'),
#  ('Allan', 'Treasury'),
#  ('Allan', 'Corporate Tax'),
#  ('Allan', 'Control And Credit'),
#  ('Allan', 'Shareholder Services'),
#  ('Allan', 'Benefits'),
#  ('Allan', 'Manufacturing'),
#  ('Allan', 'Construction'),
#  ('Allan', 'Contracting'),
#  ('Allan', 'Operations'),
#  ('Allan', 'IT Support'),
#  ('Allan', 'NOC'),
#  ('Allan', 'IT Helpdesk'),
#  ('Allan', 'Government Sales'),
#  ('Allan', 'Retail Sales'),
#  ('Allan', 'Recruiting'),
#  ('Allan', 'Payroll'),
#  ('Lindsey', '기획부'),
#  ('Lindsey', '구매부'),
#  ('Lindsey', 'Administration'),
#  ('Lindsey', 'Marketing'),
#  ('Lindsey', 'Purchasing'),
#  ('Lindsey', 'Human Resources'),
#  ('Lindsey', 'Shipping'),
#  ('Lindsey', 'IT'),
#  ('Lindsey', 'Public Relations'),
#  ('Lindsey', 'Sales'),
#  ('Lindsey', 'Executive'),
#  ('Lindsey', 'Finance'),
#  ('Lindsey', 'Accounting'),
#  ('Lindsey', 'Treasury'),
#  ('Lindsey', 'Corporate Tax'),
#  ('Lindsey', 'Control And Credit'),
#  ('Lindsey', 'Shareholder Services'),
#  ('Lindsey', 'Benefits'),
#  ('Lindsey', 'Manufacturing'),
#  ('Lindsey', 'Construction'),
#  ('Lindsey', 'Contracting'),
#  ('Lindsey', 'Operations'),
#  ('Lindsey', 'IT Support'),
#  ('Lindsey', 'NOC'),
#  ('Lindsey', 'IT Helpdesk'),
#  ('Lindsey', 'Government Sales'),
#  ('Lindsey', 'Retail Sales'),
#  ('Lindsey', 'Recruiting'),
#  ('Lindsey', 'Payroll'),
#  ('Louise', '기획부'),
#  ('Louise', '구매부'),
#  ('Louise', 'Administration'),
#  ('Louise', 'Marketing'),
#  ('Louise', 'Purchasing'),
#  ('Louise', 'Human Resources'),
#  ('Louise', 'Shipping'),
#  ('Louise', 'IT'),
#  ('Louise', 'Public Relations'),
#  ('Louise', 'Sales'),
#  ('Louise', 'Executive'),
#  ('Louise', 'Finance'),
#  ('Louise', 'Accounting'),
#  ('Louise', 'Treasury'),
#  ('Louise', 'Corporate Tax'),
#  ('Louise', 'Control And Credit'),
#  ('Louise', 'Shareholder Services'),
#  ('Louise', 'Benefits'),
#  ('Louise', 'Manufacturing'),
#  ('Louise', 'Construction'),
#  ('Louise', 'Contracting'),
#  ('Louise', 'Operations'),
#  ('Louise', 'IT Support'),
#  ('Louise', 'NOC'),
#  ('Louise', 'IT Helpdesk'),
#  ('Louise', 'Government Sales'),
#  ('Louise', 'Retail Sales'),
#  ('Louise', 'Recruiting'),
#  ('Louise', 'Payroll'),
#  ('Sarath', '기획부'),
#  ('Sarath', '구매부'),
#  ('Sarath', 'Administration'),
#  ('Sarath', 'Marketing'),
#  ('Sarath', 'Purchasing'),
#  ('Sarath', 'Human Resources'),
#  ('Sarath', 'Shipping'),
#  ('Sarath', 'IT'),
#  ('Sarath', 'Public Relations'),
#  ('Sarath', 'Sales'),
#  ('Sarath', 'Executive'),
#  ('Sarath', 'Finance'),
#  ('Sarath', 'Accounting'),
#  ('Sarath', 'Treasury'),
#  ('Sarath', 'Corporate Tax'),
#  ('Sarath', 'Control And Credit'),
#  ('Sarath', 'Shareholder Services'),
#  ('Sarath', 'Benefits'),
#  ('Sarath', 'Manufacturing'),
#  ('Sarath', 'Construction'),
#  ('Sarath', 'Contracting'),
#  ('Sarath', 'Operations'),
#  ('Sarath', 'IT Support'),
#  ('Sarath', 'NOC'),
#  ('Sarath', 'IT Helpdesk'),
#  ('Sarath', 'Government Sales'),
#  ('Sarath', 'Retail Sales'),
#  ('Sarath', 'Recruiting'),
#  ('Sarath', 'Payroll'),
#  ('Clara', '기획부'),
#  ('Clara', '구매부'),
# ...
#  ('Anthony', 'Contracting'),
#  ('Anthony', 'Operations'),
#  ('Anthony', 'IT Support'),
#  ('Anthony', 'NOC'),
#  ('Anthony', 'IT Helpdesk'),
#  ('Anthony', 'Government Sales'),
#  ('Anthony', 'Retail Sales'),
#  ('Anthony', 'Recruiting'),
#  ('Anthony', 'Payroll'),
#  ('Kelly', '기획부'),
#  ('Kelly', '구매부'),
#  ('Kelly', 'Administration'),
#  ('Kelly', 'Marketing'),
#  ('Kelly', 'Purchasing'),
#  ('Kelly', 'Human Resources'),
#  ('Kelly', 'Shipping'),
#  ('Kelly', 'IT'),
#  ('Kelly', 'Public Relations'),
#  ('Kelly', 'Sales'),
#  ('Kelly', 'Executive'),
#  ('Kelly', 'Finance'),
#  ('Kelly', 'Accounting'),
#  ('Kelly', 'Treasury'),
#  ('Kelly', 'Corporate Tax'),
#  ('Kelly', 'Control And Credit'),
#  ('Kelly', 'Shareholder Services'),
#  ('Kelly', 'Benefits'),
#  ('Kelly', 'Manufacturing'),
#  ('Kelly', 'Construction'),
#  ('Kelly', 'Contracting'),
#  ('Kelly', 'Operations'),
#  ('Kelly', 'IT Support'),
#  ('Kelly', 'NOC'),
#  ('Kelly', 'IT Helpdesk'),
#  ('Kelly', 'Government Sales'),
#  ('Kelly', 'Retail Sales'),
#  ('Kelly', 'Recruiting'),
#  ('Kelly', 'Payroll'),
#  ('Jennifer', '기획부'),
#  ('Jennifer', '구매부'),
#  ('Jennifer', 'Administration'),
#  ('Jennifer', 'Marketing'),
#  ('Jennifer', 'Purchasing'),
#  ('Jennifer', 'Human Resources'),
#  ('Jennifer', 'Shipping'),
#  ('Jennifer', 'IT'),
#  ('Jennifer', 'Public Relations'),
#  ('Jennifer', 'Sales'),
#  ('Jennifer', 'Executive'),
#  ('Jennifer', 'Finance'),
#  ('Jennifer', 'Accounting'),
#  ('Jennifer', 'Treasury'),
#  ('Jennifer', 'Corporate Tax'),
#  ('Jennifer', 'Control And Credit'),
#  ('Jennifer', 'Shareholder Services'),
#  ('Jennifer', 'Benefits'),
#  ('Jennifer', 'Manufacturing'),
#  ('Jennifer', 'Construction'),
#  ('Jennifer', 'Contracting'),
#  ('Jennifer', 'Operations'),
#  ('Jennifer', 'IT Support'),
#  ('Jennifer', 'NOC'),
#  ('Jennifer', 'IT Helpdesk'),
#  ('Jennifer', 'Government Sales'),
#  ('Jennifer', 'Retail Sales'),
#  ('Jennifer', 'Recruiting'),
#  ('Jennifer', 'Payroll'),
#  ('Timothy', '기획부'),
#  ('Timothy', '구매부'),
#  ('Timothy', 'Administration'),
#  ('Timothy', 'Marketing'),
#  ('Timothy', 'Purchasing'),
#  ('Timothy', 'Human Resources'),
#  ('Timothy', 'Shipping'),
#  ('Timothy', 'IT'),
#  ('Timothy', 'Public Relations'),
#  ('Timothy', 'Sales'),
#  ('Timothy', 'Executive'),
#  ('Timothy', 'Finance'),
#  ('Timothy', 'Accounting'),
#  ('Timothy', 'Treasury'),
#  ('Timothy', 'Corporate Tax'),
#  ('Timothy', 'Control And Credit'),
#  ('Timothy', 'Shareholder Services'),
#  ('Timothy', 'Benefits'),
#  ('Timothy', 'Manufacturing'),
#  ('Timothy', 'Construction'),
#  ('Timothy', 'Contracting'),
#  ('Timothy', 'Operations'),
#  ('Timothy', 'IT Support'),
#  ('Timothy', 'NOC'),
#  ('Timothy', 'IT Helpdesk'),
#  ('Timothy', 'Government Sales'),
#  ('Timothy', 'Retail Sales'),
#  ('Timothy', 'Recruiting'),
#  ('Timothy', 'Payroll'),
#  ('Randall', '기획부'),
#  ('Randall', '구매부'),
#  ('Randall', 'Administration'),
#  ('Randall', 'Marketing'),
#  ('Randall', 'Purchasing'),
#  ('Randall', 'Human Resources'),
#  ('Randall', 'Shipping'),
#  ('Randall', 'IT'),
#  ('Randall', 'Public Relations'),
#  ('Randall', 'Sales'),
#  ('Randall', 'Executive'),
#  ('Randall', 'Finance'),
#  ('Randall', 'Accounting'),
#  ('Randall', 'Treasury'),
#  ('Randall', 'Corporate Tax'),
#  ('Randall', 'Control And Credit'),
#  ('Randall', 'Shareholder Services'),
#  ('Randall', 'Benefits'),
#  ('Randall', 'Manufacturing'),
#  ('Randall', 'Construction'),
#  ('Randall', 'Contracting'),
#  ('Randall', 'Operations'),
#  ('Randall', 'IT Support'),
#  ('Randall', 'NOC'),
#  ('Randall', 'IT Helpdesk'),
#  ('Randall', 'Government Sales'),
#  ('Randall', 'Retail Sales'),
#  ('Randall', 'Recruiting'),
#  ('Randall', 'Payroll'),
#  ('Sarah', '기획부'),
#  ('Sarah', '구매부'),
#  ('Sarah', 'Administration'),
#  ('Sarah', 'Marketing'),
#  ('Sarah', 'Purchasing'),
#  ('Sarah', 'Human Resources'),
#  ('Sarah', 'Shipping'),
#  ('Sarah', 'IT'),
#  ('Sarah', 'Public Relations'),
#  ('Sarah', 'Sales'),
#  ('Sarah', 'Executive'),
#  ('Sarah', 'Finance'),
#  ('Sarah', 'Accounting'),
#  ('Sarah', 'Treasury'),
#  ('Sarah', 'Corporate Tax'),
#  ('Sarah', 'Control And Credit'),
#  ('Sarah', 'Shareholder Services'),
#  ('Sarah', 'Benefits'),
#  ('Sarah', 'Manufacturing'),
#  ('Sarah', 'Construction'),
#  ('Sarah', 'Contracting'),
#  ('Sarah', 'Operations'),
#  ('Sarah', 'IT Support'),
#  ('Sarah', 'NOC'),
#  ('Sarah', 'IT Helpdesk'),
#  ('Sarah', 'Government Sales'),
#  ('Sarah', 'Retail Sales'),
#  ('Sarah', 'Recruiting'),
#  ('Sarah', 'Payroll'),
#  ('Britney', '기획부'),
#  ('Britney', '구매부'),
#  ('Britney', 'Administration'),
#  ('Britney', 'Marketing'),
#  ('Britney', 'Purchasing'),
#  ('Britney', 'Human Resources'),
#  ('Britney', 'Shipping'),
#  ('Britney', 'IT'),
#  ('Britney', 'Public Relations'),
#  ('Britney', 'Sales'),
#  ('Britney', 'Executive'),
#  ('Britney', 'Finance'),
#  ('Britney', 'Accounting'),
#  ('Britney', 'Treasury'),
#  ('Britney', 'Corporate Tax'),
#  ('Britney', 'Control And Credit'),
#  ('Britney', 'Shareholder Services'),
#  ('Britney', 'Benefits'),
#  ('Britney', 'Manufacturing'),
#  ('Britney', 'Construction'),
#  ('Britney', 'Contracting'),
#  ('Britney', 'Operations'),
#  ('Britney', 'IT Support'),
#  ('Britney', 'NOC'),
#  ('Britney', 'IT Helpdesk'),
#  ('Britney', 'Government Sales'),
#  ('Britney', 'Retail Sales'),
#  ('Britney', 'Recruiting'),
#  ('Britney', 'Payroll'),
#  ('Samuel', '기획부'),
#  ('Samuel', '구매부'),
#  ('Samuel', 'Administration'),
#  ('Samuel', 'Marketing'),
#  ('Samuel', 'Purchasing'),
#  ('Samuel', 'Human Resources'),
#  ('Samuel', 'Shipping'),
#  ('Samuel', 'IT'),
#  ('Samuel', 'Public Relations'),
#  ('Samuel', 'Sales'),
#  ('Samuel', 'Executive'),
#  ('Samuel', 'Finance'),
#  ('Samuel', 'Accounting'),
#  ('Samuel', 'Treasury'),
#  ('Samuel', 'Corporate Tax'),
#  ('Samuel', 'Control And Credit'),
#  ('Samuel', 'Shareholder Services'),
#  ('Samuel', 'Benefits'),
#  ('Samuel', 'Manufacturing'),
#  ('Samuel', 'Construction'),
#  ('Samuel', 'Contracting'),
#  ('Samuel', 'Operations'),
#  ('Samuel', 'IT Support'),
#  ('Samuel', 'NOC'),
#  ('Samuel', 'IT Helpdesk'),
#  ('Samuel', 'Government Sales'),
#  ('Samuel', 'Retail Sales'),
#  ('Samuel', 'Recruiting'),
#  ('Samuel', 'Payroll'),
#  ('Vance', '기획부'),
#  ('Vance', '구매부'),
#  ('Vance', 'Administration'),
#  ('Vance', 'Marketing'),
#  ('Vance', 'Purchasing'),
#  ('Vance', 'Human Resources'),
#  ('Vance', 'Shipping'),
#  ('Vance', 'IT'),
#  ('Vance', 'Public Relations'),
#  ('Vance', 'Sales'),
#  ('Vance', 'Executive'),
#  ('Vance', 'Finance'),
#  ('Vance', 'Accounting'),
#  ('Vance', 'Treasury'),
#  ('Vance', 'Corporate Tax'),
#  ('Vance', 'Control And Credit'),
#  ('Vance', 'Shareholder Services'),
#  ('Vance', 'Benefits'),
#  ('Vance', 'Manufacturing'),
#  ('Vance', 'Construction'),
#  ('Vance', 'Contracting'),
#  ('Vance', 'Operations'),
#  ('Vance', 'IT Support'),
#  ('Vance', 'NOC'),
#  ('Vance', 'IT Helpdesk'),
#  ('Vance', 'Government Sales'),
#  ('Vance', 'Retail Sales'),
#  ('Vance', 'Recruiting'),
#  ('Vance', 'Payroll'),
#  ('Alana', '기획부'),
#  ('Alana', '구매부'),
#  ('Alana', 'Administration'),
#  ('Alana', 'Marketing'),
#  ('Alana', 'Purchasing'),
#  ('Alana', 'Human Resources'),
#  ('Alana', 'Shipping'),
#  ('Alana', 'IT'),
#  ('Alana', 'Public Relations'),
#  ('Alana', 'Sales'),
#  ('Alana', 'Executive'),
#  ('Alana', 'Finance'),
#  ('Alana', 'Accounting'),
#  ('Alana', 'Treasury'),
#  ('Alana', 'Corporate Tax'),
#  ('Alana', 'Control And Credit'),
#  ('Alana', 'Shareholder Services'),
#  ('Alana', 'Benefits'),
#  ('Alana', 'Manufacturing'),
#  ('Alana', 'Construction'),
#  ('Alana', 'Contracting'),
#  ('Alana', 'Operations'),
#  ('Alana', 'IT Support'),
#  ('Alana', 'NOC'),
#  ('Alana', 'IT Helpdesk'),
#  ('Alana', 'Government Sales'),
#  ('Alana', 'Retail Sales'),
#  ('Alana', 'Recruiting'),
#  ('Alana', 'Payroll'),
#  ('Kevin', '기획부'),
#  ('Kevin', '구매부'),
#  ('Kevin', 'Administration'),
#  ('Kevin', 'Marketing'),
#  ('Kevin', 'Purchasing'),
#  ('Kevin', 'Human Resources'),
#  ('Kevin', 'Shipping'),
#  ('Kevin', 'IT'),
#  ('Kevin', 'Public Relations'),
#  ('Kevin', 'Sales'),
#  ('Kevin', 'Executive'),
#  ('Kevin', 'Finance'),
#  ('Kevin', 'Accounting'),
#  ('Kevin', 'Treasury'),
#  ('Kevin', 'Corporate Tax'),
#  ('Kevin', 'Control And Credit'),
#  ('Kevin', 'Shareholder Services'),
#  ('Kevin', 'Benefits'),
#  ('Kevin', 'Manufacturing'),
#  ('Kevin', 'Construction'),
#  ('Kevin', 'Contracting'),
#  ('Kevin', 'Operations'),
#  ('Kevin', 'IT Support'),
#  ('Kevin', 'NOC'),
#  ('Kevin', 'IT Helpdesk'),
#  ('Kevin', 'Government Sales'),
#  ('Kevin', 'Retail Sales'),
#  ('Kevin', 'Recruiting'),
#  ('Kevin', 'Payroll'),
#  ('Donald', '기획부'),
#  ('Donald', '구매부'),
#  ('Donald', 'Administration'),
#  ('Donald', 'Marketing'),
#  ('Donald', 'Purchasing'),
#  ('Donald', 'Human Resources'),
#  ('Donald', 'Shipping'),
#  ('Donald', 'IT'),
#  ('Donald', 'Public Relations'),
#  ('Donald', 'Sales'),
#  ('Donald', 'Executive'),
#  ('Donald', 'Finance'),
#  ('Donald', 'Accounting'),
#  ('Donald', 'Treasury'),
#  ('Donald', 'Corporate Tax'),
#  ('Donald', 'Control And Credit'),
#  ('Donald', 'Shareholder Services'),
#  ('Donald', 'Benefits'),
#  ('Donald', 'Manufacturing'),
#  ('Donald', 'Construction'),
#  ('Donald', 'Contracting'),
#  ('Donald', 'Operations'),
#  ('Donald', 'IT Support'),
#  ('Donald', 'NOC'),
#  ('Donald', 'IT Helpdesk'),
#  ('Donald', 'Government Sales'),
#  ('Donald', 'Retail Sales'),
#  ('Donald', 'Recruiting'),
#  ('Donald', 'Payroll'),
#  ('Douglas', '기획부'),
#  ('Douglas', '구매부'),
#  ('Douglas', 'Administration'),
#  ('Douglas', 'Marketing'),
#  ('Douglas', 'Purchasing'),
#  ('Douglas', 'Human Resources'),
#  ('Douglas', 'Shipping'),
#  ('Douglas', 'IT'),
#  ('Douglas', 'Public Relations'),
#  ('Douglas', 'Sales'),
#  ('Douglas', 'Executive'),
#  ('Douglas', 'Finance'),
#  ('Douglas', 'Accounting'),
#  ('Douglas', 'Treasury'),
#  ('Douglas', 'Corporate Tax'),
#  ('Douglas', 'Control And Credit'),
#  ('Douglas', 'Shareholder Services'),
#  ('Douglas', 'Benefits'),
#  ('Douglas', 'Manufacturing'),
#  ('Douglas', 'Construction'),
#  ('Douglas', 'Contracting'),
#  ('Douglas', 'Operations'),
#  ('Douglas', 'IT Support'),
#  ('Douglas', 'NOC'),
#  ('Douglas', 'IT Helpdesk'),
#  ('Douglas', 'Government Sales'),
#  ('Douglas', 'Retail Sales'),
#  ('Douglas', 'Recruiting'),
#  ('Douglas', 'Payroll'),
#  ('Jennifer', '기획부'),
#  ('Jennifer', '구매부'),
#  ('Jennifer', 'Administration'),
#  ('Jennifer', 'Marketing'),
#  ('Jennifer', 'Purchasing'),
#  ('Jennifer', 'Human Resources'),
#  ('Jennifer', 'Shipping'),
#  ('Jennifer', 'IT'),
#  ('Jennifer', 'Public Relations'),
#  ('Jennifer', 'Sales'),
#  ('Jennifer', 'Executive'),
#  ('Jennifer', 'Finance'),
#  ('Jennifer', 'Accounting'),
#  ('Jennifer', 'Treasury'),
#  ('Jennifer', 'Corporate Tax'),
#  ('Jennifer', 'Control And Credit'),
#  ('Jennifer', 'Shareholder Services'),
#  ('Jennifer', 'Benefits'),
#  ('Jennifer', 'Manufacturing'),
#  ('Jennifer', 'Construction'),
#  ('Jennifer', 'Contracting'),
#  ('Jennifer', 'Operations'),
#  ('Jennifer', 'IT Support'),
#  ('Jennifer', 'NOC'),
#  ('Jennifer', 'IT Helpdesk'),
#  ('Jennifer', 'Government Sales'),
#  ('Jennifer', 'Retail Sales'),
#  ('Jennifer', 'Recruiting'),
#  ('Jennifer', 'Payroll'),
#  ('Michael', '기획부'),
#  ('Michael', '구매부'),
#  ('Michael', 'Administration'),
#  ('Michael', 'Marketing'),
#  ('Michael', 'Purchasing'),
#  ('Michael', 'Human Resources'),
#  ('Michael', 'Shipping'),
#  ('Michael', 'IT'),
#  ('Michael', 'Public Relations'),
#  ('Michael', 'Sales'),
#  ('Michael', 'Executive'),
#  ('Michael', 'Finance'),
#  ('Michael', 'Accounting'),
#  ('Michael', 'Treasury'),
#  ('Michael', 'Corporate Tax'),
#  ('Michael', 'Control And Credit'),
#  ('Michael', 'Shareholder Services'),
#  ('Michael', 'Benefits'),
#  ('Michael', 'Manufacturing'),
#  ('Michael', 'Construction'),
#  ('Michael', 'Contracting'),
#  ('Michael', 'Operations'),
#  ('Michael', 'IT Support'),
#  ('Michael', 'NOC'),
#  ('Michael', 'IT Helpdesk'),
#  ('Michael', 'Government Sales'),
#  ('Michael', 'Retail Sales'),
#  ('Michael', 'Recruiting'),
#  ('Michael', 'Payroll'),
#  ('Pat', '기획부'),
#  ('Pat', '구매부'),
#  ('Pat', 'Administration'),
#  ('Pat', 'Marketing'),
#  ('Pat', 'Purchasing'),
#  ('Pat', 'Human Resources'),
#  ('Pat', 'Shipping'),
#  ('Pat', 'IT'),
#  ('Pat', 'Public Relations'),
#  ('Pat', 'Sales'),
#  ('Pat', 'Executive'),
#  ('Pat', 'Finance'),
#  ('Pat', 'Accounting'),
#  ('Pat', 'Treasury'),
#  ('Pat', 'Corporate Tax'),
#  ('Pat', 'Control And Credit'),
#  ('Pat', 'Shareholder Services'),
#  ('Pat', 'Benefits'),
#  ('Pat', 'Manufacturing'),
#  ('Pat', 'Construction'),
#  ('Pat', 'Contracting'),
#  ('Pat', 'Operations'),
#  ('Pat', 'IT Support'),
#  ('Pat', 'NOC'),
#  ('Pat', 'IT Helpdesk'),
#  ('Pat', 'Government Sales'),
#  ('Pat', 'Retail Sales'),
#  ('Pat', 'Recruiting'),
#  ('Pat', 'Payroll'),
#  ('Susan', '기획부'),
#  ('Susan', '구매부'),
#  ('Susan', 'Administration'),
#  ('Susan', 'Marketing'),
#  ('Susan', 'Purchasing'),
#  ('Susan', 'Human Resources'),
#  ('Susan', 'Shipping'),
#  ('Susan', 'IT'),
#  ('Susan', 'Public Relations'),
#  ('Susan', 'Sales'),
#  ('Susan', 'Executive'),
#  ('Susan', 'Finance'),
#  ('Susan', 'Accounting'),
#  ('Susan', 'Treasury'),
#  ('Susan', 'Corporate Tax'),
#  ('Susan', 'Control And Credit'),
#  ('Susan', 'Shareholder Services'),
#  ('Susan', 'Benefits'),
#  ('Susan', 'Manufacturing'),
#  ('Susan', 'Construction'),
#  ('Susan', 'Contracting'),
#  ('Susan', 'Operations'),
#  ('Susan', 'IT Support'),
#  ('Susan', 'NOC'),
#  ('Susan', 'IT Helpdesk'),
#  ('Susan', 'Government Sales'),
#  ('Susan', 'Retail Sales'),
#  ('Susan', 'Recruiting'),
#  ('Susan', 'Payroll'),
#  ('Hermann', '기획부'),
#  ('Hermann', '구매부'),
#  ('Hermann', 'Administration'),
#  ('Hermann', 'Marketing'),
#  ('Hermann', 'Purchasing'),
#  ('Hermann', 'Human Resources'),
#  ('Hermann', 'Shipping'),
#  ('Hermann', 'IT'),
#  ('Hermann', 'Public Relations'),
#  ('Hermann', 'Sales'),
#  ('Hermann', 'Executive'),
#  ('Hermann', 'Finance'),
#  ('Hermann', 'Accounting'),
#  ('Hermann', 'Treasury'),
#  ('Hermann', 'Corporate Tax'),
#  ('Hermann', 'Control And Credit'),
#  ('Hermann', 'Shareholder Services'),
#  ('Hermann', 'Benefits'),
#  ('Hermann', 'Manufacturing'),
#  ('Hermann', 'Construction'),
#  ('Hermann', 'Contracting'),
#  ('Hermann', 'Operations'),
#  ('Hermann', 'IT Support'),
#  ('Hermann', 'NOC'),
#  ('Hermann', 'IT Helpdesk'),
#  ('Hermann', 'Government Sales'),
#  ('Hermann', 'Retail Sales'),
#  ('Hermann', 'Recruiting'),
#  ('Hermann', 'Payroll'),
#  ('Shelley', '기획부'),
#  ('Shelley', '구매부'),
#  ('Shelley', 'Administration'),
#  ('Shelley', 'Marketing'),
#  ('Shelley', 'Purchasing'),
#  ('Shelley', 'Human Resources'),
#  ('Shelley', 'Shipping'),
#  ('Shelley', 'IT'),
#  ('Shelley', 'Public Relations'),
#  ('Shelley', 'Sales'),
#  ('Shelley', 'Executive'),
#  ('Shelley', 'Finance'),
#  ('Shelley', 'Accounting'),
#  ('Shelley', 'Treasury'),
#  ('Shelley', 'Corporate Tax'),
#  ('Shelley', 'Control And Credit'),
#  ('Shelley', 'Shareholder Services'),
#  ('Shelley', 'Benefits'),
#  ('Shelley', 'Manufacturing'),
#  ('Shelley', 'Construction'),
#  ('Shelley', 'Contracting'),
#  ('Shelley', 'Operations'),
#  ('Shelley', 'IT Support'),
#  ('Shelley', 'NOC'),
#  ('Shelley', 'IT Helpdesk'),
#  ('Shelley', 'Government Sales'),
#  ('Shelley', 'Retail Sales'),
#  ('Shelley', 'Recruiting'),
#  ('Shelley', 'Payroll'),
#  ('William', '기획부'),
#  ('William', '구매부'),
#  ('William', 'Administration'),
#  ('William', 'Marketing'),
#  ('William', 'Purchasing'),
#  ('William', 'Human Resources'),
#  ('William', 'Shipping'),
#  ('William', 'IT'),
#  ('William', 'Public Relations'),
#  ('William', 'Sales'),
#  ('William', 'Executive'),
#  ('William', 'Finance'),
#  ('William', 'Accounting'),
#  ('William', 'Treasury'),
#  ('William', 'Corporate Tax'),
#  ('William', 'Control And Credit'),
#  ('William', 'Shareholder Services'),
#  ('William', 'Benefits'),
#  ('William', 'Manufacturing'),
#  ('William', 'Construction'),
#  ('William', 'Contracting'),
#  ('William', 'Operations'),
#  ('William', 'IT Support'),
#  ('William', 'NOC'),
#  ('William', 'IT Helpdesk'),
#  ('William', 'Government Sales'),
#  ('William', 'Retail Sales'),
#  ('William', 'Recruiting'),
#  ('William', 'Payroll'),
#  ('홍길동', '기획부'),
#  ('홍길동', '구매부'),
#  ('홍길동', 'Administration'),
#  ('홍길동', 'Marketing'),
#  ('홍길동', 'Purchasing'),
#  ('홍길동', 'Human Resources'),
#  ('홍길동', 'Shipping'),
#  ('홍길동', 'IT'),
#  ('홍길동', 'Public Relations'),
#  ('홍길동', 'Sales'),
#  ('홍길동', 'Executive'),
#  ('홍길동', 'Finance'),
#  ('홍길동', 'Accounting'),
#  ('홍길동', 'Treasury'),
#  ('홍길동', 'Corporate Tax'),
#  ('홍길동', 'Control And Credit'),
#  ('홍길동', 'Shareholder Services'),
#  ('홍길동', 'Benefits'),
#  ('홍길동', 'Manufacturing'),
#  ('홍길동', 'Construction'),
#  ('홍길동', 'Contracting'),
#  ('홍길동', 'Operations'),
#  ('홍길동', 'IT Support'),
#  ('홍길동', 'NOC'),
#  ('홍길동', 'IT Helpdesk'),
#  ('홍길동', 'Government Sales'),
#  ('홍길동', 'Retail Sales'),
#  ('홍길동', 'Recruiting'),
#  ('홍길동', 'Payroll')]

# %% [markdown]
# ## INSERT / UPDATE/ DELETE
# - SQL 실행 후 Connection객체의 commit()을 호출 해야 최종적으로 적용된다.
# - commit()
#     - 최종 적용
# - rollback()
#     - 변경전 상태로 되돌리기
#
# ### 사용할 테이블
# ```sql
# create table test(
#     id varchar2(10),
#     name varchar2(100),
#     age number(3));
# ```

# %% [markdown]
# ## batch(일괄작업) 처리
# - 한번에 메소드 호출로 다수 행을 처리한다.
# - executemany(sql, placeholder에 전달할값)
#     - placeholder에 전달할 값을 list로 묶어서 전달하면 sql문이 그 개수만큼 한번에 처리된다.

# %% [markdown]
# ## TODO : 매개변수로 dept_id를 받아서 EMP 테이블에서 그 부서의 직원들의 salary를 두배 update하는 함수.

# %% [markdown]
# ## TODO : 매개변수로 job_id를 받아서 그 업무를 하는 직원들을 EMP 테이블에서 삭제하는 함수.

# %% [markdown]
# # TODO : 매개변수로 직원 이름을 입력받아 EMP 테이블에서 그  직원들의 전체 정보를 조회결과를 출력하는 함수.

# %% [markdown]
# # TODO: 사용자로 부터 직원정보를 입력받아 EMP 테이블에 입력한다.
# - emp_id, emp_name, job_id, mgr_id, hire_date, salary, comm_pct, dept_id 를 하나씩 입력받는다.
# - job_id, mgr_id, salary, comm_pct, dept_id 을 입력하지 않은 경우 NULL 을 넣는다. (placehold 사용시 None을 대입)
# - 입력된 값을 EMP 테이블에 insert 한다.
# - 주의 job_id, mgr_id, dept_id는 FK 컬럼이므로 부모테이블의 PK값을 넣어야 한다.
